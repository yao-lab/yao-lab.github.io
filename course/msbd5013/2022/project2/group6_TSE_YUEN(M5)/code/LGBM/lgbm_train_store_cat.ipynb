# %%
import numpy as np
import pandas as pd
import os
import time
import lightgbm as lgb
import seaborn as sns
import matplotlib.pyplot as plt
import gc
import pickle
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
# load data
process_df = pd.read_pickle('processed.pkl')

# since we do it by store and category, store_id, cat_id are useless
# dept_id is useful
unused_features = [
    'id',
    'state_id',
    'store_id',
    'cat_id',
    # 'dept_id',
    'date',
    'wm_yr_wk',
    'd',
    'sales',
    'revenue'
]

# retrieve training features
used_features = process_df.columns[~process_df.columns.isin(unused_features)]

FIRST_DAY = 0
STORES = ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3']
CATEGORIES = ['HOBBIES', 'HOUSEHOLD', 'FOODS']

def prepare_data(df, store, category):
    df = df[df['d'] >= FIRST_DAY]
    df = df[(df['store_id'] == store) & (df['cat_id'] == category)]
    return df

# lightgbm params
params = {'boosting_type': 'gbdt',
          'metric': 'rmse',
          'objective': 'regression',
          'n_jobs': -1,
          'seed': 5013,
          'learning_rate': 0.01,
          'bagging_fraction': 0.75,
          'bagging_freq': 10, 
          'colsample_bytree': 0.75, 
          'force_col_wise': True
         }

model_dir = './models_store_cat/'

# %%
for store in STORES:
    for category in CATEGORIES:
        print('starting:',store,category)
        
        # get train and val data
        train_df = prepare_data(process_df,store,category)
        x_train = train_df[(train_df['date'] <= '2016-03-27')]
        y_train = x_train['sales']
        x_val = train_df[(train_df['date'] > '2016-03-27') & (train_df['date'] <= '2016-04-24')]
        y_val = x_val['sales']
        
        # create train and val dataset
        lgb_train = lgb.Dataset(x_train[used_features], y_train)
        lgb_val = lgb.Dataset(x_val[used_features], y_val)
        
        # model training
        model = lgb.train(params, lgb_train, num_boost_round = 2500, early_stopping_rounds = 50, 
                          valid_sets = [lgb_train, lgb_val], verbose_eval = 100
                         )
        
        # store model
        model_name = store+'_'+category+'.bin'
        pickle.dump(model, open(os.path.join(model_dir,model_name), 'wb'))
        
        del train_df, x_train, y_train, x_val, y_val, lgb_train, lgb_val
        gc.collect()
# Out:
# starting: CA_1 HOBBIES
# [LightGBM] [Info] Total Bins 3743
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.809019
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.34958	valid_1's rmse: 2.25166
# [200]	training's rmse: 2.2516	valid_1's rmse: 2.16561
# [300]	training's rmse: 2.22005	valid_1's rmse: 2.14872
# [400]	training's rmse: 2.20136	valid_1's rmse: 2.1454
# [500]	training's rmse: 2.18634	valid_1's rmse: 2.14447
# Early stopping, best iteration is:
# [520]	training's rmse: 2.18386	valid_1's rmse: 2.14307
# starting: CA_1 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4012
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.715687
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.25284	valid_1's rmse: 1.54144
# [200]	training's rmse: 1.17451	valid_1's rmse: 1.43484
# [300]	training's rmse: 1.15373	valid_1's rmse: 1.41197
# [400]	training's rmse: 1.14414	valid_1's rmse: 1.40577
# [500]	training's rmse: 1.13748	valid_1's rmse: 1.40249
# [600]	training's rmse: 1.1324	valid_1's rmse: 1.40047
# [700]	training's rmse: 1.12815	valid_1's rmse: 1.39906
# [800]	training's rmse: 1.12453	valid_1's rmse: 1.39814
# [900]	training's rmse: 1.12117	valid_1's rmse: 1.39729
# [1000]	training's rmse: 1.11794	valid_1's rmse: 1.39629
# Early stopping, best iteration is:
# [1019]	training's rmse: 1.11735	valid_1's rmse: 1.39614
# starting: CA_1 FOODS
# [LightGBM] [Info] Total Bins 4874
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.955208
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.67846	valid_1's rmse: 2.92193
# [200]	training's rmse: 3.26896	valid_1's rmse: 2.63574
# [300]	training's rmse: 3.14944	valid_1's rmse: 2.58083
# [400]	training's rmse: 3.08545	valid_1's rmse: 2.5685
# [500]	training's rmse: 3.04433	valid_1's rmse: 2.56162
# Early stopping, best iteration is:
# [505]	training's rmse: 3.04293	valid_1's rmse: 2.56129
# starting: CA_2 HOBBIES
# [LightGBM] [Info] Total Bins 3635
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.587926
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.7764	valid_1's rmse: 1.75393
# [200]	training's rmse: 1.71587	valid_1's rmse: 1.70545
# [300]	training's rmse: 1.69567	valid_1's rmse: 1.69571
# [400]	training's rmse: 1.68332	valid_1's rmse: 1.69318
# [500]	training's rmse: 1.67401	valid_1's rmse: 1.69221
# Early stopping, best iteration is:
# [508]	training's rmse: 1.67329	valid_1's rmse: 1.69216
# starting: CA_2 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4090
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.778153
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.40649	valid_1's rmse: 1.56294
# [200]	training's rmse: 1.32014	valid_1's rmse: 1.48618
# [300]	training's rmse: 1.29317	valid_1's rmse: 1.46902
# [400]	training's rmse: 1.27966	valid_1's rmse: 1.46196
# [500]	training's rmse: 1.26997	valid_1's rmse: 1.45911
# [600]	training's rmse: 1.26252	valid_1's rmse: 1.45635
# [700]	training's rmse: 1.25631	valid_1's rmse: 1.45552
# [800]	training's rmse: 1.25045	valid_1's rmse: 1.45502
# [900]	training's rmse: 1.24523	valid_1's rmse: 1.45333
# [1000]	training's rmse: 1.24054	valid_1's rmse: 1.45265
# Early stopping, best iteration is:
# [979]	training's rmse: 1.24143	valid_1's rmse: 1.45245
# starting: CA_2 FOODS
# [LightGBM] [Info] Total Bins 4691
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.254651
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.50512	valid_1's rmse: 2.86458
# [200]	training's rmse: 2.3046	valid_1's rmse: 2.61605
# [300]	training's rmse: 2.24943	valid_1's rmse: 2.55474
# [400]	training's rmse: 2.22124	valid_1's rmse: 2.53401
# [500]	training's rmse: 2.20136	valid_1's rmse: 2.52327
# [600]	training's rmse: 2.18643	valid_1's rmse: 2.51288
# [700]	training's rmse: 2.17448	valid_1's rmse: 2.50805
# [800]	training's rmse: 2.16251	valid_1's rmse: 2.50373
# [900]	training's rmse: 2.15242	valid_1's rmse: 2.49873
# [1000]	training's rmse: 2.14255	valid_1's rmse: 2.49259
# Early stopping, best iteration is:
# [1036]	training's rmse: 2.13906	valid_1's rmse: 2.4911
# starting: CA_3 HOBBIES
# [LightGBM] [Info] Total Bins 3853
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.887217
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.45403	valid_1's rmse: 2.34259
# [200]	training's rmse: 2.33104	valid_1's rmse: 2.2624
# [300]	training's rmse: 2.28762	valid_1's rmse: 2.25223
# [400]	training's rmse: 2.26087	valid_1's rmse: 2.247
# Early stopping, best iteration is:
# [383]	training's rmse: 2.26501	valid_1's rmse: 2.24563
# starting: CA_3 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4326
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 1.348582
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.37871	valid_1's rmse: 2.49987
# [200]	training's rmse: 2.12881	valid_1's rmse: 2.26283
# [300]	training's rmse: 2.06545	valid_1's rmse: 2.21658
# [400]	training's rmse: 2.03752	valid_1's rmse: 2.20316
# [500]	training's rmse: 2.01887	valid_1's rmse: 2.1986
# [600]	training's rmse: 2.00472	valid_1's rmse: 2.19545
# [700]	training's rmse: 1.99376	valid_1's rmse: 2.19405
# Early stopping, best iteration is:
# [675]	training's rmse: 1.99645	valid_1's rmse: 2.19399
# starting: CA_3 FOODS
# [LightGBM] [Info] Total Bins 5102
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 2.733644
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 5.34623	valid_1's rmse: 3.93343
# [200]	training's rmse: 4.63907	valid_1's rmse: 3.45485
# [300]	training's rmse: 4.43104	valid_1's rmse: 3.36883
# [400]	training's rmse: 4.33327	valid_1's rmse: 3.35287
# [500]	training's rmse: 4.26598	valid_1's rmse: 3.34484
# [600]	training's rmse: 4.21978	valid_1's rmse: 3.3436
# Early stopping, best iteration is:
# [613]	training's rmse: 4.21391	valid_1's rmse: 3.34183
# starting: CA_4 HOBBIES
# [LightGBM] [Info] Total Bins 3604
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.520304
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.59547	valid_1's rmse: 1.56998
# [200]	training's rmse: 1.52629	valid_1's rmse: 1.52544
# [300]	training's rmse: 1.50622	valid_1's rmse: 1.5226
# Early stopping, best iteration is:
# [282]	training's rmse: 1.50884	valid_1's rmse: 1.52255
# starting: CA_4 HOUSEHOLD
# [LightGBM] [Info] Total Bins 3805
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.356837
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.782297	valid_1's rmse: 0.932941
# [200]	training's rmse: 0.758234	valid_1's rmse: 0.904004
# [300]	training's rmse: 0.751546	valid_1's rmse: 0.896211
# [400]	training's rmse: 0.748215	valid_1's rmse: 0.893778
# [500]	training's rmse: 0.745738	valid_1's rmse: 0.892335
# [600]	training's rmse: 0.743158	valid_1's rmse: 0.891839
# [700]	training's rmse: 0.741616	valid_1's rmse: 0.891454
# [800]	training's rmse: 0.739937	valid_1's rmse: 0.891005
# [900]	training's rmse: 0.738229	valid_1's rmse: 0.890539
# [1000]	training's rmse: 0.73664	valid_1's rmse: 0.890062
# [1100]	training's rmse: 0.734839	valid_1's rmse: 0.889767
# [1200]	training's rmse: 0.73339	valid_1's rmse: 0.889571
# Early stopping, best iteration is:
# [1151]	training's rmse: 0.73417	valid_1's rmse: 0.889536
# starting: CA_4 FOODS
# [LightGBM] [Info] Total Bins 4617
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.023010
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.86104	valid_1's rmse: 1.74094
# [200]	training's rmse: 1.72569	valid_1's rmse: 1.65349
# [300]	training's rmse: 1.68818	valid_1's rmse: 1.64026
# [400]	training's rmse: 1.66995	valid_1's rmse: 1.63836
# Early stopping, best iteration is:
# [392]	training's rmse: 1.67141	valid_1's rmse: 1.63774
# starting: TX_1 HOBBIES
# [LightGBM] [Info] Total Bins 3546
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.395334
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.32994	valid_1's rmse: 1.51711
# [200]	training's rmse: 1.2997	valid_1's rmse: 1.49301
# [300]	training's rmse: 1.28815	valid_1's rmse: 1.48723
# [400]	training's rmse: 1.28058	valid_1's rmse: 1.48642
# [500]	training's rmse: 1.27431	valid_1's rmse: 1.48629
# Early stopping, best iteration is:
# [517]	training's rmse: 1.27335	valid_1's rmse: 1.4859
# starting: TX_1 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4126
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.690111
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.52687	valid_1's rmse: 1.45842
# [200]	training's rmse: 1.41719	valid_1's rmse: 1.37067
# [300]	training's rmse: 1.38482	valid_1's rmse: 1.35709
# Early stopping, best iteration is:
# [344]	training's rmse: 1.37735	valid_1's rmse: 1.35604
# starting: TX_1 FOODS
# [LightGBM] [Info] Total Bins 4820
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.373136
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.98416	valid_1's rmse: 2.60234
# [200]	training's rmse: 2.66615	valid_1's rmse: 2.28895
# [300]	training's rmse: 2.57584	valid_1's rmse: 2.22238
# [400]	training's rmse: 2.53073	valid_1's rmse: 2.19561
# [500]	training's rmse: 2.5011	valid_1's rmse: 2.1872
# [600]	training's rmse: 2.47961	valid_1's rmse: 2.17779
# [700]	training's rmse: 2.46088	valid_1's rmse: 2.17464
# Early stopping, best iteration is:
# [689]	training's rmse: 2.46277	valid_1's rmse: 2.1744
# starting: TX_2 HOBBIES
# [LightGBM] [Info] Total Bins 3580
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.587168
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.56391	valid_1's rmse: 1.48354
# [200]	training's rmse: 1.51698	valid_1's rmse: 1.4537
# [300]	training's rmse: 1.50094	valid_1's rmse: 1.45126
# Early stopping, best iteration is:
# [295]	training's rmse: 1.50152	valid_1's rmse: 1.45121
# starting: TX_2 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4136
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.778098
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.85169	valid_1's rmse: 1.53189
# [200]	training's rmse: 1.73796	valid_1's rmse: 1.4998
# Early stopping, best iteration is:
# [167]	training's rmse: 1.76181	valid_1's rmse: 1.49905
# starting: TX_2 FOODS
# [LightGBM] [Info] Total Bins 4993
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.824933
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.75056	valid_1's rmse: 2.61398
# [200]	training's rmse: 3.23985	valid_1's rmse: 2.28732
# [300]	training's rmse: 3.10223	valid_1's rmse: 2.27773
# Early stopping, best iteration is:
# [255]	training's rmse: 3.14684	valid_1's rmse: 2.2724
# starting: TX_3 HOBBIES
# [LightGBM] [Info] Total Bins 3597
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.484391
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.37353	valid_1's rmse: 1.60176
# [200]	training's rmse: 1.32416	valid_1's rmse: 1.52833
# [300]	training's rmse: 1.30888	valid_1's rmse: 1.51993
# [400]	training's rmse: 1.2999	valid_1's rmse: 1.51986
# Early stopping, best iteration is:
# [379]	training's rmse: 1.30167	valid_1's rmse: 1.51894
# starting: TX_3 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4141
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.695472
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.43283	valid_1's rmse: 1.3755
# [200]	training's rmse: 1.31411	valid_1's rmse: 1.33735
# Early stopping, best iteration is:
# [174]	training's rmse: 1.331	valid_1's rmse: 1.33548
# starting: TX_3 FOODS
# [LightGBM] [Info] Total Bins 4924
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.511563
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.3014	valid_1's rmse: 2.59804
# [200]	training's rmse: 2.87316	valid_1's rmse: 2.32168
# [300]	training's rmse: 2.75563	valid_1's rmse: 2.30443
# Early stopping, best iteration is:
# [297]	training's rmse: 2.75771	valid_1's rmse: 2.3044
# starting: WI_1 HOBBIES
# [LightGBM] [Info] Total Bins 3616
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.604702
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.56592	valid_1's rmse: 1.59744
# [200]	training's rmse: 1.48771	valid_1's rmse: 1.52253
# [300]	training's rmse: 1.4638	valid_1's rmse: 1.50809
# [400]	training's rmse: 1.45119	valid_1's rmse: 1.50607
# [500]	training's rmse: 1.44135	valid_1's rmse: 1.50414
# [600]	training's rmse: 1.43326	valid_1's rmse: 1.50318
# Early stopping, best iteration is:
# [592]	training's rmse: 1.43379	valid_1's rmse: 1.50305
# starting: WI_1 HOUSEHOLD
# [LightGBM] [Info] Total Bins 3985
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.523542
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.03203	valid_1's rmse: 1.18762
# [200]	training's rmse: 0.977029	valid_1's rmse: 1.13988
# [300]	training's rmse: 0.959822	valid_1's rmse: 1.13351
# [400]	training's rmse: 0.951205	valid_1's rmse: 1.13272
# [500]	training's rmse: 0.944965	valid_1's rmse: 1.13207
# Early stopping, best iteration is:
# [522]	training's rmse: 0.943955	valid_1's rmse: 1.13166
# starting: WI_1 FOODS
# [LightGBM] [Info] Total Bins 4676
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.242088
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.21438	valid_1's rmse: 2.29951
# [200]	training's rmse: 2.0281	valid_1's rmse: 2.1411
# [300]	training's rmse: 1.97826	valid_1's rmse: 2.11181
# [400]	training's rmse: 1.95143	valid_1's rmse: 2.10621
# [500]	training's rmse: 1.93381	valid_1's rmse: 2.10316
# [600]	training's rmse: 1.92055	valid_1's rmse: 2.10075
# Early stopping, best iteration is:
# [617]	training's rmse: 1.91858	valid_1's rmse: 2.09888
# starting: WI_2 HOBBIES
# [LightGBM] [Info] Total Bins 3548
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.339972
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.15473	valid_1's rmse: 1.32123
# [200]	training's rmse: 1.12022	valid_1's rmse: 1.28684
# [300]	training's rmse: 1.10613	valid_1's rmse: 1.27961
# [400]	training's rmse: 1.09723	valid_1's rmse: 1.27724
# [500]	training's rmse: 1.08982	valid_1's rmse: 1.27674
# [600]	training's rmse: 1.08335	valid_1's rmse: 1.2765
# Early stopping, best iteration is:
# [578]	training's rmse: 1.08473	valid_1's rmse: 1.27604
# starting: WI_2 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4216
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.696186
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.6159	valid_1's rmse: 1.92719
# [200]	training's rmse: 1.46586	valid_1's rmse: 1.73927
# [300]	training's rmse: 1.41887	valid_1's rmse: 1.69734
# [400]	training's rmse: 1.39548	valid_1's rmse: 1.68202
# [500]	training's rmse: 1.3798	valid_1's rmse: 1.67635
# [600]	training's rmse: 1.36757	valid_1's rmse: 1.67269
# [700]	training's rmse: 1.35705	valid_1's rmse: 1.6703
# [800]	training's rmse: 1.34837	valid_1's rmse: 1.66686
# [900]	training's rmse: 1.34021	valid_1's rmse: 1.66569
# [1000]	training's rmse: 1.33233	valid_1's rmse: 1.66441
# Early stopping, best iteration is:
# [1025]	training's rmse: 1.33063	valid_1's rmse: 1.66276
# starting: WI_2 FOODS
# [LightGBM] [Info] Total Bins 4867
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.719204
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.82877	valid_1's rmse: 4.75437
# [200]	training's rmse: 3.5515	valid_1's rmse: 4.27973
# [300]	training's rmse: 3.47034	valid_1's rmse: 4.13124
# [400]	training's rmse: 3.42472	valid_1's rmse: 4.08268
# [500]	training's rmse: 3.39019	valid_1's rmse: 4.05092
# [600]	training's rmse: 3.36184	valid_1's rmse: 4.02125
# [700]	training's rmse: 3.3372	valid_1's rmse: 4.00061
# [800]	training's rmse: 3.31324	valid_1's rmse: 3.98656
# [900]	training's rmse: 3.29143	valid_1's rmse: 3.97095
# [1000]	training's rmse: 3.27133	valid_1's rmse: 3.96693
# Early stopping, best iteration is:
# [1016]	training's rmse: 3.26797	valid_1's rmse: 3.96525
# starting: WI_3 HOBBIES
# [LightGBM] [Info] Total Bins 3539
# [LightGBM] [Info] Number of data points in the train set: 1065025, number of used features: 31
# [LightGBM] [Info] Start training from score 0.430806
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.32065	valid_1's rmse: 1.39866
# [200]	training's rmse: 1.28395	valid_1's rmse: 1.37653
# [300]	training's rmse: 1.27049	valid_1's rmse: 1.37338
# [400]	training's rmse: 1.2619	valid_1's rmse: 1.37306
# Early stopping, best iteration is:
# [401]	training's rmse: 1.26182	valid_1's rmse: 1.37305
# starting: WI_3 HOUSEHOLD
# [LightGBM] [Info] Total Bins 4079
# [LightGBM] [Info] Number of data points in the train set: 1973595, number of used features: 31
# [LightGBM] [Info] Start training from score 0.611690
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.30013	valid_1's rmse: 1.36502
# [200]	training's rmse: 1.19611	valid_1's rmse: 1.27333
# [300]	training's rmse: 1.16434	valid_1's rmse: 1.25751
# [400]	training's rmse: 1.14851	valid_1's rmse: 1.25364
# [500]	training's rmse: 1.13721	valid_1's rmse: 1.25242
# [600]	training's rmse: 1.1291	valid_1's rmse: 1.25142
# [700]	training's rmse: 1.12256	valid_1's rmse: 1.25037
# [800]	training's rmse: 1.11712	valid_1's rmse: 1.25
# [900]	training's rmse: 1.11169	valid_1's rmse: 1.24988
# Early stopping, best iteration is:
# [872]	training's rmse: 1.11323	valid_1's rmse: 1.24976
# starting: WI_3 FOODS
# [LightGBM] [Info] Total Bins 4912
# [LightGBM] [Info] Number of data points in the train set: 2708745, number of used features: 31
# [LightGBM] [Info] Start training from score 1.716634
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.77926	valid_1's rmse: 3.30968
# [200]	training's rmse: 3.3448	valid_1's rmse: 2.84821
# [300]	training's rmse: 3.21402	valid_1's rmse: 2.71951
# [400]	training's rmse: 3.13741	valid_1's rmse: 2.67565
# [500]	training's rmse: 3.08684	valid_1's rmse: 2.65293
# [600]	training's rmse: 3.04721	valid_1's rmse: 2.64722
# Early stopping, best iteration is:
# [566]	training's rmse: 3.05915	valid_1's rmse: 2.64583
