# %%
import numpy as np
import pandas as pd
import os
import time
import lightgbm as lgb
import seaborn as sns
import matplotlib.pyplot as plt
import gc
import pickle
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
# load data
process_df = pd.read_pickle('processed.pkl')

# since we do it by store and department, store_id, cat_id, dept_id are useless
unused_features = [
    'id',
    'state_id',
    'store_id',
    'cat_id',
    'dept_id',
    'date',
    'wm_yr_wk',
    'd',
    'sales',
    'revenue'
]

# retrieve training features
used_features = process_df.columns[~process_df.columns.isin(unused_features)]

FIRST_DAY = 0
STORES = ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3']
DEPTS = ['HOBBIES_1', 'HOBBIES_2', 'HOUSEHOLD_1', 'HOUSEHOLD_2', 'FOODS_1', 'FOODS_2', 'FOODS_3']

def prepare_data(df, store, state):
    df = df[df['d'] >= FIRST_DAY]
    df = df[(df['store_id'] == store) & (df['dept_id'] == state)]
    return df

# lightgbm params
params = {'boosting_type': 'gbdt',
          'metric': 'rmse',
          'objective': 'regression',
          'n_jobs': -1,
          'seed': 5013,
          'learning_rate': 0.01,
          'bagging_fraction': 0.75,
          'bagging_freq': 10, 
          'colsample_bytree': 0.75, 
          'force_col_wise': True
         }

model_dir = './models_store_dept/'

# %%
for store in STORES:
    for state in DEPTS:
        print('starting:',store,state)
        
        # get train and val data
        train_df = prepare_data(process_df,store,state)
        x_train = train_df[(train_df['date'] <= '2016-03-27')]
        y_train = x_train['sales']
        x_val = train_df[(train_df['date'] > '2016-03-27') & (train_df['date'] <= '2016-04-24')]
        y_val = x_val['sales']
        
        # create train and val dataset
        lgb_train = lgb.Dataset(x_train[used_features], y_train)
        lgb_val = lgb.Dataset(x_val[used_features], y_val)
        
        # model training
        model = lgb.train(params, lgb_train, num_boost_round = 2500, early_stopping_rounds = 50, 
                          valid_sets = [lgb_train, lgb_val], verbose_eval = 100
                         )
        
        # store model
        model_name = store+'_'+state+'.bin'
        pickle.dump(model, open(os.path.join(model_dir,model_name), 'wb'))
        
        del train_df, x_train, y_train, x_val, y_val, lgb_train, lgb_val
        gc.collect()
# Out:
# starting: CA_1 HOBBIES_1
# [LightGBM] [Info] Total Bins 3628
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.029370
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.73121	valid_1's rmse: 2.60627
# [200]	training's rmse: 2.60479	valid_1's rmse: 2.48915
# [300]	training's rmse: 2.57261	valid_1's rmse: 2.46351
# [400]	training's rmse: 2.55553	valid_1's rmse: 2.45461
# [500]	training's rmse: 2.54111	valid_1's rmse: 2.45244
# Early stopping, best iteration is:
# [510]	training's rmse: 2.53983	valid_1's rmse: 2.4522
# starting: CA_1 HOBBIES_2
# [LightGBM] [Info] Total Bins 2714
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.647169
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.723755	valid_1's rmse: 0.713867
# [200]	training's rmse: 0.701454	valid_1's rmse: 0.702873
# [300]	training's rmse: 0.688852	valid_1's rmse: 0.69957
# [400]	training's rmse: 0.679012	valid_1's rmse: 0.698214
# Early stopping, best iteration is:
# [424]	training's rmse: 0.677322	valid_1's rmse: 0.698159
# starting: CA_1 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3493
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score 0.072437
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.61642	valid_1's rmse: 2.055
# [200]	training's rmse: 1.49472	valid_1's rmse: 1.88594
# [300]	training's rmse: 1.46207	valid_1's rmse: 1.84749
# [400]	training's rmse: 1.44751	valid_1's rmse: 1.8335
# [500]	training's rmse: 1.439	valid_1's rmse: 1.82865
# [600]	training's rmse: 1.42975	valid_1's rmse: 1.82414
# [700]	training's rmse: 1.42313	valid_1's rmse: 1.82252
# [800]	training's rmse: 1.41529	valid_1's rmse: 1.82156
# Early stopping, best iteration is:
# [797]	training's rmse: 1.41573	valid_1's rmse: 1.82151
# starting: CA_1 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 3112
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.065999
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.713625	valid_1's rmse: 0.802055
# [200]	training's rmse: 0.6957	valid_1's rmse: 0.777587
# [300]	training's rmse: 0.690014	valid_1's rmse: 0.770745
# [400]	training's rmse: 0.686854	valid_1's rmse: 0.767941
# [500]	training's rmse: 0.684816	valid_1's rmse: 0.766855
# [600]	training's rmse: 0.683171	valid_1's rmse: 0.766102
# Early stopping, best iteration is:
# [610]	training's rmse: 0.683028	valid_1's rmse: 0.766078
# starting: CA_1 FOODS_1
# [LightGBM] [Info] Total Bins 3315
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.318431
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.34713	valid_1's rmse: 1.92563
# [200]	training's rmse: 2.16125	valid_1's rmse: 1.89703
# Early stopping, best iteration is:
# [158]	training's rmse: 2.21003	valid_1's rmse: 1.88958
# starting: CA_1 FOODS_2
# [LightGBM] [Info] Total Bins 3602
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score 0.148280
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.13627	valid_1's rmse: 1.9064
# [200]	training's rmse: 1.88512	valid_1's rmse: 1.73373
# [300]	training's rmse: 1.82131	valid_1's rmse: 1.69235
# [400]	training's rmse: 1.79252	valid_1's rmse: 1.68169
# [500]	training's rmse: 1.77213	valid_1's rmse: 1.67784
# [600]	training's rmse: 1.7559	valid_1's rmse: 1.67765
# Early stopping, best iteration is:
# [579]	training's rmse: 1.75889	valid_1's rmse: 1.67719
# starting: CA_1 FOODS_3
# [LightGBM] [Info] Total Bins 4319
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.913139
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 4.67983	valid_1's rmse: 3.57792
# [200]	training's rmse: 4.04402	valid_1's rmse: 3.12807
# [300]	training's rmse: 3.8682	valid_1's rmse: 3.04556
# [400]	training's rmse: 3.77839	valid_1's rmse: 3.01956
# [500]	training's rmse: 3.72763	valid_1's rmse: 3.00728
# [600]	training's rmse: 3.68295	valid_1's rmse: 3.00177
# [700]	training's rmse: 3.64017	valid_1's rmse: 2.99719
# [800]	training's rmse: 3.6108	valid_1's rmse: 2.99359
# [900]	training's rmse: 3.57759	valid_1's rmse: 2.98786
# [1000]	training's rmse: 3.54572	valid_1's rmse: 2.98475
# [1100]	training's rmse: 3.51536	valid_1's rmse: 2.98199
# Early stopping, best iteration is:
# [1092]	training's rmse: 3.51737	valid_1's rmse: 2.98086
# starting: CA_2 HOBBIES_1
# [LightGBM] [Info] Total Bins 3495
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.322925
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.04274	valid_1's rmse: 2.00353
# [200]	training's rmse: 1.9634	valid_1's rmse: 1.93774
# [300]	training's rmse: 1.94207	valid_1's rmse: 1.92554
# [400]	training's rmse: 1.93017	valid_1's rmse: 1.92351
# Early stopping, best iteration is:
# [415]	training's rmse: 1.92859	valid_1's rmse: 1.9232
# starting: CA_2 HOBBIES_2
# [LightGBM] [Info] Total Bins 2747
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.570524
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.713913	valid_1's rmse: 0.754187
# [200]	training's rmse: 0.694667	valid_1's rmse: 0.749359
# [300]	training's rmse: 0.684759	valid_1's rmse: 0.74834
# [400]	training's rmse: 0.677251	valid_1's rmse: 0.748135
# Early stopping, best iteration is:
# [385]	training's rmse: 0.678099	valid_1's rmse: 0.748067
# starting: CA_2 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3574
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score 0.077929
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.77067	valid_1's rmse: 1.85475
# [200]	training's rmse: 1.63867	valid_1's rmse: 1.75527
# [300]	training's rmse: 1.6006	valid_1's rmse: 1.73532
# [400]	training's rmse: 1.57814	valid_1's rmse: 1.73039
# [500]	training's rmse: 1.56555	valid_1's rmse: 1.7276
# [600]	training's rmse: 1.55394	valid_1's rmse: 1.72624
# [700]	training's rmse: 1.54468	valid_1's rmse: 1.72433
# [800]	training's rmse: 1.53572	valid_1's rmse: 1.72404
# Early stopping, best iteration is:
# [759]	training's rmse: 1.53896	valid_1's rmse: 1.72343
# starting: CA_2 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 3393
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -0.765154
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.918155	valid_1's rmse: 1.19127
# [200]	training's rmse: 0.885965	valid_1's rmse: 1.13901
# [300]	training's rmse: 0.876644	valid_1's rmse: 1.12076
# [400]	training's rmse: 0.871007	valid_1's rmse: 1.11395
# [500]	training's rmse: 0.866691	valid_1's rmse: 1.1082
# [600]	training's rmse: 0.861869	valid_1's rmse: 1.1008
# [700]	training's rmse: 0.85803	valid_1's rmse: 1.10041
# [800]	training's rmse: 0.855184	valid_1's rmse: 1.09961
# Early stopping, best iteration is:
# [757]	training's rmse: 0.856342	valid_1's rmse: 1.09873
# starting: CA_2 FOODS_1
# [LightGBM] [Info] Total Bins 3394
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.549289
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.88297	valid_1's rmse: 2.7084
# [200]	training's rmse: 2.70715	valid_1's rmse: 2.55817
# [300]	training's rmse: 2.64323	valid_1's rmse: 2.52855
# [400]	training's rmse: 2.60088	valid_1's rmse: 2.52326
# [500]	training's rmse: 2.5684	valid_1's rmse: 2.51812
# [600]	training's rmse: 2.54365	valid_1's rmse: 2.51222
# Early stopping, best iteration is:
# [588]	training's rmse: 2.54581	valid_1's rmse: 2.51198
# starting: CA_2 FOODS_2
# [LightGBM] [Info] Total Bins 3274
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score -0.856396
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.10078	valid_1's rmse: 1.74817
# [200]	training's rmse: 1.00394	valid_1's rmse: 1.62009
# [300]	training's rmse: 0.976999	valid_1's rmse: 1.58977
# [400]	training's rmse: 0.964384	valid_1's rmse: 1.58059
# [500]	training's rmse: 0.955799	valid_1's rmse: 1.57939
# Early stopping, best iteration is:
# [477]	training's rmse: 0.95772	valid_1's rmse: 1.57842
# starting: CA_2 FOODS_3
# [LightGBM] [Info] Total Bins 4085
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.425744
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.94241	valid_1's rmse: 3.44164
# [200]	training's rmse: 2.62976	valid_1's rmse: 3.03681
# [300]	training's rmse: 2.54885	valid_1's rmse: 2.93892
# [400]	training's rmse: 2.50647	valid_1's rmse: 2.9041
# [500]	training's rmse: 2.48037	valid_1's rmse: 2.88278
# [600]	training's rmse: 2.45904	valid_1's rmse: 2.86266
# [700]	training's rmse: 2.44126	valid_1's rmse: 2.84602
# [800]	training's rmse: 2.42566	valid_1's rmse: 2.83977
# [900]	training's rmse: 2.41087	valid_1's rmse: 2.82787
# [1000]	training's rmse: 2.39822	valid_1's rmse: 2.82518
# [1100]	training's rmse: 2.38343	valid_1's rmse: 2.8165
# [1200]	training's rmse: 2.36938	valid_1's rmse: 2.81462
# Early stopping, best iteration is:
# [1189]	training's rmse: 2.37097	valid_1's rmse: 2.81363
# starting: CA_3 HOBBIES_1
# [LightGBM] [Info] Total Bins 3722
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.104985
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.86584	valid_1's rmse: 2.69975
# [200]	training's rmse: 2.71067	valid_1's rmse: 2.5967
# [300]	training's rmse: 2.6665	valid_1's rmse: 2.58742
# Early stopping, best iteration is:
# [312]	training's rmse: 2.6632	valid_1's rmse: 2.58653
# starting: CA_3 HOBBIES_2
# [LightGBM] [Info] Total Bins 2788
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.334539
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.8341	valid_1's rmse: 0.843309
# [200]	training's rmse: 0.810001	valid_1's rmse: 0.831913
# [300]	training's rmse: 0.799445	valid_1's rmse: 0.830363
# Early stopping, best iteration is:
# [281]	training's rmse: 0.801322	valid_1's rmse: 0.830184
# starting: CA_3 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3800
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score 0.742108
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.23331	valid_1's rmse: 3.37116
# [200]	training's rmse: 2.83138	valid_1's rmse: 3.01029
# [300]	training's rmse: 2.73596	valid_1's rmse: 2.93634
# [400]	training's rmse: 2.69857	valid_1's rmse: 2.9155
# [500]	training's rmse: 2.67402	valid_1's rmse: 2.90578
# [600]	training's rmse: 2.65571	valid_1's rmse: 2.90139
# [700]	training's rmse: 2.63997	valid_1's rmse: 2.8979
# [800]	training's rmse: 2.62638	valid_1's rmse: 2.89544
# Early stopping, best iteration is:
# [760]	training's rmse: 2.63208	valid_1's rmse: 2.89533
# starting: CA_3 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 3412
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -0.558635
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.05623	valid_1's rmse: 1.14129
# [200]	training's rmse: 1.01379	valid_1's rmse: 1.08836
# [300]	training's rmse: 1.00154	valid_1's rmse: 1.07115
# [400]	training's rmse: 0.994782	valid_1's rmse: 1.06448
# [500]	training's rmse: 0.990321	valid_1's rmse: 1.06125
# [600]	training's rmse: 0.986757	valid_1's rmse: 1.05746
# [700]	training's rmse: 0.983495	valid_1's rmse: 1.05565
# [800]	training's rmse: 0.980735	valid_1's rmse: 1.05511
# Early stopping, best iteration is:
# [760]	training's rmse: 0.981764	valid_1's rmse: 1.05462
# starting: CA_3 FOODS_1
# [LightGBM] [Info] Total Bins 3447
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.579082
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.0013	valid_1's rmse: 2.34505
# Early stopping, best iteration is:
# [138]	training's rmse: 2.90221	valid_1's rmse: 2.32846
# starting: CA_3 FOODS_2
# [LightGBM] [Info] Total Bins 3664
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score 0.455573
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.63015	valid_1's rmse: 2.14897
# [200]	training's rmse: 2.27691	valid_1's rmse: 1.98088
# [300]	training's rmse: 2.18796	valid_1's rmse: 1.9465
# [400]	training's rmse: 2.15498	valid_1's rmse: 1.93702
# [500]	training's rmse: 2.13528	valid_1's rmse: 1.93422
# [600]	training's rmse: 2.11988	valid_1's rmse: 1.9318
# [700]	training's rmse: 2.10342	valid_1's rmse: 1.92807
# Early stopping, best iteration is:
# [736]	training's rmse: 2.09706	valid_1's rmse: 1.92755
# starting: CA_3 FOODS_3
# [LightGBM] [Info] Total Bins 4607
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 1.264717
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.13794	valid_1's rmse: 4.99524
# [200]	training's rmse: 6.00119	valid_1's rmse: 4.13926
# [300]	training's rmse: 5.67486	valid_1's rmse: 4.02853
# [400]	training's rmse: 5.5374	valid_1's rmse: 3.99836
# [500]	training's rmse: 5.45481	valid_1's rmse: 3.98344
# [600]	training's rmse: 5.39169	valid_1's rmse: 3.96305
# [700]	training's rmse: 5.3364	valid_1's rmse: 3.95282
# [800]	training's rmse: 5.28554	valid_1's rmse: 3.94133
# [900]	training's rmse: 5.23777	valid_1's rmse: 3.94156
# Early stopping, best iteration is:
# [890]	training's rmse: 5.24432	valid_1's rmse: 3.93621
# starting: CA_4 HOBBIES_1
# [LightGBM] [Info] Total Bins 3462
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.388013
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.86374	valid_1's rmse: 1.82806
# [200]	training's rmse: 1.77247	valid_1's rmse: 1.76444
# [300]	training's rmse: 1.75273	valid_1's rmse: 1.76409
# Early stopping, best iteration is:
# [270]	training's rmse: 1.75642	valid_1's rmse: 1.76188
# starting: CA_4 HOBBIES_2
# [LightGBM] [Info] Total Bins 2192
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -2.539585
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.392829	valid_1's rmse: 0.385598
# [200]	training's rmse: 0.385004	valid_1's rmse: 0.385187
# Early stopping, best iteration is:
# [189]	training's rmse: 0.385712	valid_1's rmse: 0.385086
# starting: CA_4 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3291
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score -0.657593
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.920626	valid_1's rmse: 1.15428
# [200]	training's rmse: 0.886326	valid_1's rmse: 1.11455
# [300]	training's rmse: 0.877644	valid_1's rmse: 1.10442
# [400]	training's rmse: 0.873737	valid_1's rmse: 1.10031
# [500]	training's rmse: 0.871231	valid_1's rmse: 1.0978
# [600]	training's rmse: 0.868969	valid_1's rmse: 1.09609
# [700]	training's rmse: 0.866824	valid_1's rmse: 1.0954
# Early stopping, best iteration is:
# [719]	training's rmse: 0.866396	valid_1's rmse: 1.09527
# starting: CA_4 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 2992
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.659394
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.595792	valid_1's rmse: 0.626186
# [200]	training's rmse: 0.569614	valid_1's rmse: 0.609214
# [300]	training's rmse: 0.541995	valid_1's rmse: 0.603893
# [400]	training's rmse: 0.532711	valid_1's rmse: 0.60165
# [500]	training's rmse: 0.527957	valid_1's rmse: 0.600716
# [600]	training's rmse: 0.516481	valid_1's rmse: 0.600088
# [700]	training's rmse: 0.513291	valid_1's rmse: 0.599641
# [800]	training's rmse: 0.50868	valid_1's rmse: 0.599384
# [900]	training's rmse: 0.504463	valid_1's rmse: 0.599053
# Early stopping, best iteration is:
# [907]	training's rmse: 0.504435	valid_1's rmse: 0.598942
# starting: CA_4 FOODS_1
# [LightGBM] [Info] Total Bins 3194
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.187028
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.60227	valid_1's rmse: 1.51951
# [200]	training's rmse: 1.47882	valid_1's rmse: 1.46488
# Early stopping, best iteration is:
# [201]	training's rmse: 1.4783	valid_1's rmse: 1.46485
# starting: CA_4 FOODS_2
# [LightGBM] [Info] Total Bins 3341
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score -0.353265
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.25002	valid_1's rmse: 1.35719
# [200]	training's rmse: 1.18003	valid_1's rmse: 1.29459
# [300]	training's rmse: 1.16199	valid_1's rmse: 1.27953
# [400]	training's rmse: 1.1529	valid_1's rmse: 1.27481
# [500]	training's rmse: 1.14714	valid_1's rmse: 1.27298
# [600]	training's rmse: 1.14245	valid_1's rmse: 1.27107
# [700]	training's rmse: 1.13864	valid_1's rmse: 1.26989
# [800]	training's rmse: 1.13525	valid_1's rmse: 1.26843
# [900]	training's rmse: 1.13225	valid_1's rmse: 1.26644
# [1000]	training's rmse: 1.12954	valid_1's rmse: 1.26516
# Early stopping, best iteration is:
# [1047]	training's rmse: 1.12817	valid_1's rmse: 1.26504
# starting: CA_4 FOODS_3
# [LightGBM] [Info] Total Bins 4022
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.206094
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.20606	valid_1's rmse: 1.98117
# [200]	training's rmse: 2.00283	valid_1's rmse: 1.85035
# [300]	training's rmse: 1.94717	valid_1's rmse: 1.83034
# [400]	training's rmse: 1.92199	valid_1's rmse: 1.82691
# [500]	training's rmse: 1.90844	valid_1's rmse: 1.82486
# [600]	training's rmse: 1.8959	valid_1's rmse: 1.82383
# [700]	training's rmse: 1.88598	valid_1's rmse: 1.82205
# [800]	training's rmse: 1.87696	valid_1's rmse: 1.81932
# [900]	training's rmse: 1.86734	valid_1's rmse: 1.81853
# Early stopping, best iteration is:
# [915]	training's rmse: 1.86629	valid_1's rmse: 1.81803
# starting: TX_1 HOBBIES_1
# [LightGBM] [Info] Total Bins 3405
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.727312
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.51411	valid_1's rmse: 1.73447
# [200]	training's rmse: 1.47787	valid_1's rmse: 1.702
# [300]	training's rmse: 1.46639	valid_1's rmse: 1.69499
# [400]	training's rmse: 1.45719	valid_1's rmse: 1.69306
# [500]	training's rmse: 1.45014	valid_1's rmse: 1.69242
# [600]	training's rmse: 1.44222	valid_1's rmse: 1.69123
# Early stopping, best iteration is:
# [591]	training's rmse: 1.44318	valid_1's rmse: 1.69102
# starting: TX_1 HOBBIES_2
# [LightGBM] [Info] Total Bins 2649
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.897114
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.597534	valid_1's rmse: 0.651734
# [200]	training's rmse: 0.583777	valid_1's rmse: 0.646782
# [300]	training's rmse: 0.576234	valid_1's rmse: 0.645599
# [400]	training's rmse: 0.56944	valid_1's rmse: 0.645258
# Early stopping, best iteration is:
# [444]	training's rmse: 0.566902	valid_1's rmse: 0.645224
# starting: TX_1 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3623
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score 0.115129
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.97914	valid_1's rmse: 1.81851
# [200]	training's rmse: 1.8023	valid_1's rmse: 1.7152
# Early stopping, best iteration is:
# [235]	training's rmse: 1.7815	valid_1's rmse: 1.71182
# starting: TX_1 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 3210
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.410803
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.870385	valid_1's rmse: 0.954563
# [200]	training's rmse: 0.77675	valid_1's rmse: 0.822185
# [300]	training's rmse: 0.736702	valid_1's rmse: 0.790663
# [400]	training's rmse: 0.691499	valid_1's rmse: 0.783938
# [500]	training's rmse: 0.661667	valid_1's rmse: 0.782128
# Early stopping, best iteration is:
# [479]	training's rmse: 0.668012	valid_1's rmse: 0.781938
# starting: TX_1 FOODS_1
# [LightGBM] [Info] Total Bins 3251
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.122858
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.83695	valid_1's rmse: 1.70921
# [200]	training's rmse: 1.73382	valid_1's rmse: 1.66716
# Early stopping, best iteration is:
# [210]	training's rmse: 1.72857	valid_1's rmse: 1.66659
# starting: TX_1 FOODS_2
# [LightGBM] [Info] Total Bins 3386
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score -0.188646
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.66477	valid_1's rmse: 1.52529
# [200]	training's rmse: 1.54857	valid_1's rmse: 1.41014
# [300]	training's rmse: 1.49849	valid_1's rmse: 1.37438
# [400]	training's rmse: 1.44339	valid_1's rmse: 1.3617
# [500]	training's rmse: 1.4156	valid_1's rmse: 1.35597
# [600]	training's rmse: 1.40114	valid_1's rmse: 1.35439
# Early stopping, best iteration is:
# [624]	training's rmse: 1.39802	valid_1's rmse: 1.35387
# starting: TX_1 FOODS_3
# [LightGBM] [Info] Total Bins 4288
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.568149
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.87182	valid_1's rmse: 3.28627
# [200]	training's rmse: 3.33648	valid_1's rmse: 2.76093
# [300]	training's rmse: 3.19454	valid_1's rmse: 2.63765
# [400]	training's rmse: 3.13218	valid_1's rmse: 2.61185
# [500]	training's rmse: 3.08788	valid_1's rmse: 2.59753
# [600]	training's rmse: 3.05674	valid_1's rmse: 2.58731
# [700]	training's rmse: 3.03052	valid_1's rmse: 2.57625
# Early stopping, best iteration is:
# [708]	training's rmse: 3.02879	valid_1's rmse: 2.57468
# starting: TX_2 HOBBIES_1
# [LightGBM] [Info] Total Bins 3446
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.352370
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.73161	valid_1's rmse: 1.63592
# [200]	training's rmse: 1.67052	valid_1's rmse: 1.58894
# [300]	training's rmse: 1.65225	valid_1's rmse: 1.58317
# [400]	training's rmse: 1.64046	valid_1's rmse: 1.58243
# Early stopping, best iteration is:
# [371]	training's rmse: 1.64341	valid_1's rmse: 1.58224
# starting: TX_2 HOBBIES_2
# [LightGBM] [Info] Total Bins 2891
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.332877
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.977486	valid_1's rmse: 0.97451
# [200]	training's rmse: 0.935483	valid_1's rmse: 0.9715
# [300]	training's rmse: 0.91218	valid_1's rmse: 0.971713
# Early stopping, best iteration is:
# [263]	training's rmse: 0.91911	valid_1's rmse: 0.971324
# starting: TX_2 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3646
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score 0.206167
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.53935	valid_1's rmse: 2.01791
# [200]	training's rmse: 2.37503	valid_1's rmse: 1.95238
# Early stopping, best iteration is:
# [192]	training's rmse: 2.38199	valid_1's rmse: 1.9513
# starting: TX_2 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 3171
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.163613
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.696345	valid_1's rmse: 0.777507
# [200]	training's rmse: 0.680112	valid_1's rmse: 0.753959
# [300]	training's rmse: 0.674746	valid_1's rmse: 0.746358
# [400]	training's rmse: 0.671168	valid_1's rmse: 0.740107
# [500]	training's rmse: 0.668777	valid_1's rmse: 0.73618
# [600]	training's rmse: 0.666726	valid_1's rmse: 0.733989
# [700]	training's rmse: 0.66511	valid_1's rmse: 0.732463
# [800]	training's rmse: 0.663537	valid_1's rmse: 0.731569
# [900]	training's rmse: 0.662346	valid_1's rmse: 0.730927
# Early stopping, best iteration is:
# [920]	training's rmse: 0.662092	valid_1's rmse: 0.730831
# starting: TX_2 FOODS_1
# [LightGBM] [Info] Total Bins 3512
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.209597
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.5432	valid_1's rmse: 1.62677
# [200]	training's rmse: 2.23559	valid_1's rmse: 1.47103
# [300]	training's rmse: 2.14475	valid_1's rmse: 1.44595
# [400]	training's rmse: 2.09611	valid_1's rmse: 1.43981
# [500]	training's rmse: 2.06288	valid_1's rmse: 1.43916
# Early stopping, best iteration is:
# [521]	training's rmse: 2.05703	valid_1's rmse: 1.43777
# starting: TX_2 FOODS_2
# [LightGBM] [Info] Total Bins 3506
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score 0.026098
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.84415	valid_1's rmse: 1.43838
# [200]	training's rmse: 1.67898	valid_1's rmse: 1.37776
# Early stopping, best iteration is:
# [210]	training's rmse: 1.67172	valid_1's rmse: 1.37704
# starting: TX_2 FOODS_3
# [LightGBM] [Info] Total Bins 4465
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.861365
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 4.97456	valid_1's rmse: 3.42175
# [200]	training's rmse: 4.07664	valid_1's rmse: 2.77639
# Early stopping, best iteration is:
# [249]	training's rmse: 3.92095	valid_1's rmse: 2.74819
# starting: TX_3 HOBBIES_1
# [LightGBM] [Info] Total Bins 3474
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.554719
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.54499	valid_1's rmse: 1.84246
# [200]	training's rmse: 1.47214	valid_1's rmse: 1.68904
# [300]	training's rmse: 1.45371	valid_1's rmse: 1.66382
# [400]	training's rmse: 1.44374	valid_1's rmse: 1.6601
# Early stopping, best iteration is:
# [390]	training's rmse: 1.44463	valid_1's rmse: 1.65999
# starting: TX_3 HOBBIES_2
# [LightGBM] [Info] Total Bins 2796
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.454329
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.811483	valid_1's rmse: 1.01852
# [200]	training's rmse: 0.790341	valid_1's rmse: 1.00962
# [300]	training's rmse: 0.777366	valid_1's rmse: 1.00671
# [400]	training's rmse: 0.766324	valid_1's rmse: 1.00511
# [500]	training's rmse: 0.755676	valid_1's rmse: 1.00445
# [600]	training's rmse: 0.745025	valid_1's rmse: 1.00369
# [700]	training's rmse: 0.734778	valid_1's rmse: 1.00361
# Early stopping, best iteration is:
# [650]	training's rmse: 0.73895	valid_1's rmse: 1.00353
# starting: TX_3 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3647
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score 0.127054
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.95545	valid_1's rmse: 1.80035
# [200]	training's rmse: 1.7726	valid_1's rmse: 1.72573
# Early stopping, best iteration is:
# [189]	training's rmse: 1.78215	valid_1's rmse: 1.72501
# starting: TX_3 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 2994
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.423201
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.583382	valid_1's rmse: 0.705548
# [200]	training's rmse: 0.568909	valid_1's rmse: 0.687518
# [300]	training's rmse: 0.564592	valid_1's rmse: 0.683037
# [400]	training's rmse: 0.562111	valid_1's rmse: 0.681546
# [500]	training's rmse: 0.560315	valid_1's rmse: 0.680946
# [600]	training's rmse: 0.558808	valid_1's rmse: 0.680471
# [700]	training's rmse: 0.557634	valid_1's rmse: 0.68008
# [800]	training's rmse: 0.556528	valid_1's rmse: 0.679873
# Early stopping, best iteration is:
# [840]	training's rmse: 0.556264	valid_1's rmse: 0.679794
# starting: TX_3 FOODS_1
# [LightGBM] [Info] Total Bins 3381
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.007841
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.05886	valid_1's rmse: 2.17572
# [200]	training's rmse: 1.87033	valid_1's rmse: 1.85228
# [300]	training's rmse: 1.81799	valid_1's rmse: 1.77515
# [400]	training's rmse: 1.79265	valid_1's rmse: 1.75102
# [500]	training's rmse: 1.77319	valid_1's rmse: 1.74035
# [600]	training's rmse: 1.75706	valid_1's rmse: 1.7369
# [700]	training's rmse: 1.74069	valid_1's rmse: 1.72976
# [800]	training's rmse: 1.72747	valid_1's rmse: 1.727
# Early stopping, best iteration is:
# [764]	training's rmse: 1.73104	valid_1's rmse: 1.72485
# starting: TX_3 FOODS_2
# [LightGBM] [Info] Total Bins 3607
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score -0.013500
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.90373	valid_1's rmse: 1.83613
# [200]	training's rmse: 1.69736	valid_1's rmse: 1.71593
# [300]	training's rmse: 1.64128	valid_1's rmse: 1.68331
# [400]	training's rmse: 1.60995	valid_1's rmse: 1.67347
# [500]	training's rmse: 1.58945	valid_1's rmse: 1.66917
# [600]	training's rmse: 1.57527	valid_1's rmse: 1.66603
# Early stopping, best iteration is:
# [613]	training's rmse: 1.57347	valid_1's rmse: 1.66531
# starting: TX_3 FOODS_3
# [LightGBM] [Info] Total Bins 4378
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.642774
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 4.3248	valid_1's rmse: 3.15876
# [200]	training's rmse: 3.58166	valid_1's rmse: 2.64878
# [300]	training's rmse: 3.38258	valid_1's rmse: 2.63217
# Early stopping, best iteration is:
# [259]	training's rmse: 3.43821	valid_1's rmse: 2.62317
# starting: WI_1 HOBBIES_1
# [LightGBM] [Info] Total Bins 3476
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.272143
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.81675	valid_1's rmse: 1.82952
# [200]	training's rmse: 1.71079	valid_1's rmse: 1.72898
# [300]	training's rmse: 1.68262	valid_1's rmse: 1.71064
# [400]	training's rmse: 1.66826	valid_1's rmse: 1.70639
# Early stopping, best iteration is:
# [439]	training's rmse: 1.66403	valid_1's rmse: 1.70611
# starting: WI_1 HOBBIES_2
# [LightGBM] [Info] Total Bins 2545
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.794280
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.585118	valid_1's rmse: 0.687586
# [200]	training's rmse: 0.573802	valid_1's rmse: 0.684005
# [300]	training's rmse: 0.568605	valid_1's rmse: 0.683165
# [400]	training's rmse: 0.56471	valid_1's rmse: 0.68286
# [500]	training's rmse: 0.56129	valid_1's rmse: 0.682664
# [600]	training's rmse: 0.557795	valid_1's rmse: 0.682584
# Early stopping, best iteration is:
# [616]	training's rmse: 0.557301	valid_1's rmse: 0.68246
# starting: WI_1 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3464
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score -0.218447
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.33631	valid_1's rmse: 1.52817
# [200]	training's rmse: 1.2567	valid_1's rmse: 1.45183
# [300]	training's rmse: 1.23378	valid_1's rmse: 1.4395
# [400]	training's rmse: 1.22187	valid_1's rmse: 1.4354
# [500]	training's rmse: 1.21447	valid_1's rmse: 1.43399
# Early stopping, best iteration is:
# [522]	training's rmse: 1.21315	valid_1's rmse: 1.43389
# starting: WI_1 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 3111
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.452150
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.576709	valid_1's rmse: 0.685058
# [200]	training's rmse: 0.563598	valid_1's rmse: 0.671824
# [300]	training's rmse: 0.558971	valid_1's rmse: 0.670193
# [400]	training's rmse: 0.556302	valid_1's rmse: 0.670145
# Early stopping, best iteration is:
# [360]	training's rmse: 0.55725	valid_1's rmse: 0.670044
# starting: WI_1 FOODS_1
# [LightGBM] [Info] Total Bins 3295
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.202010
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.08847	valid_1's rmse: 1.98877
# [200]	training's rmse: 1.93352	valid_1's rmse: 1.83442
# [300]	training's rmse: 1.88588	valid_1's rmse: 1.80384
# [400]	training's rmse: 1.85397	valid_1's rmse: 1.79198
# Early stopping, best iteration is:
# [400]	training's rmse: 1.85397	valid_1's rmse: 1.79198
# starting: WI_1 FOODS_2
# [LightGBM] [Info] Total Bins 3431
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score -0.253755
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.45235	valid_1's rmse: 2.00195
# [200]	training's rmse: 1.35597	valid_1's rmse: 1.83775
# [300]	training's rmse: 1.32465	valid_1's rmse: 1.79768
# [400]	training's rmse: 1.30571	valid_1's rmse: 1.78062
# [500]	training's rmse: 1.2911	valid_1's rmse: 1.76794
# [600]	training's rmse: 1.27917	valid_1's rmse: 1.75785
# [700]	training's rmse: 1.27075	valid_1's rmse: 1.74949
# [800]	training's rmse: 1.26244	valid_1's rmse: 1.74749
# [900]	training's rmse: 1.25526	valid_1's rmse: 1.74544
# Early stopping, best iteration is:
# [920]	training's rmse: 1.25399	valid_1's rmse: 1.74469
# starting: WI_1 FOODS_3
# [LightGBM] [Info] Total Bins 4059
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.386844
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.6111	valid_1's rmse: 2.59078
# [200]	training's rmse: 2.31225	valid_1's rmse: 2.33952
# [300]	training's rmse: 2.23655	valid_1's rmse: 2.30196
# [400]	training's rmse: 2.19838	valid_1's rmse: 2.29532
# [500]	training's rmse: 2.17654	valid_1's rmse: 2.29162
# [600]	training's rmse: 2.15793	valid_1's rmse: 2.28997
# [700]	training's rmse: 2.14051	valid_1's rmse: 2.2886
# [800]	training's rmse: 2.12361	valid_1's rmse: 2.28698
# [900]	training's rmse: 2.10936	valid_1's rmse: 2.28558
# [1000]	training's rmse: 2.09556	valid_1's rmse: 2.28483
# [1100]	training's rmse: 2.08454	valid_1's rmse: 2.28148
# Early stopping, best iteration is:
# [1107]	training's rmse: 2.08398	valid_1's rmse: 2.28141
# starting: WI_2 HOBBIES_1
# [LightGBM] [Info] Total Bins 3412
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.892353
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.3064	valid_1's rmse: 1.47362
# [200]	training's rmse: 1.26059	valid_1's rmse: 1.42627
# [300]	training's rmse: 1.24519	valid_1's rmse: 1.4164
# [400]	training's rmse: 1.2345	valid_1's rmse: 1.41393
# [500]	training's rmse: 1.22442	valid_1's rmse: 1.41294
# [600]	training's rmse: 1.21633	valid_1's rmse: 1.41149
# Early stopping, best iteration is:
# [629]	training's rmse: 1.21459	valid_1's rmse: 1.41133
# starting: WI_2 HOBBIES_2
# [LightGBM] [Info] Total Bins 2670
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.928800
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.602448	valid_1's rmse: 0.787932
# [200]	training's rmse: 0.587452	valid_1's rmse: 0.778359
# [300]	training's rmse: 0.579797	valid_1's rmse: 0.775614
# Early stopping, best iteration is:
# [309]	training's rmse: 0.578848	valid_1's rmse: 0.775425
# starting: WI_2 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3739
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score 0.168721
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.25261	valid_1's rmse: 2.72242
# [200]	training's rmse: 2.01273	valid_1's rmse: 2.38279
# [300]	training's rmse: 1.94308	valid_1's rmse: 2.29945
# [400]	training's rmse: 1.90865	valid_1's rmse: 2.2633
# [500]	training's rmse: 1.88705	valid_1's rmse: 2.25067
# [600]	training's rmse: 1.87054	valid_1's rmse: 2.24214
# [700]	training's rmse: 1.85696	valid_1's rmse: 2.23611
# [800]	training's rmse: 1.84419	valid_1's rmse: 2.23281
# [900]	training's rmse: 1.83236	valid_1's rmse: 2.22901
# [1000]	training's rmse: 1.82416	valid_1's rmse: 2.22589
# [1100]	training's rmse: 1.81644	valid_1's rmse: 2.22446
# Early stopping, best iteration is:
# [1077]	training's rmse: 1.81829	valid_1's rmse: 2.22379
# starting: WI_2 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 3089
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.647730
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.533	valid_1's rmse: 0.618497
# [200]	training's rmse: 0.515711	valid_1's rmse: 0.600481
# [300]	training's rmse: 0.510587	valid_1's rmse: 0.597609
# Early stopping, best iteration is:
# [346]	training's rmse: 0.509058	valid_1's rmse: 0.597259
# starting: WI_2 FOODS_1
# [LightGBM] [Info] Total Bins 3462
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score 0.245388
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.69292	valid_1's rmse: 3.41034
# [200]	training's rmse: 2.38705	valid_1's rmse: 2.72612
# [300]	training's rmse: 2.30607	valid_1's rmse: 2.49567
# [400]	training's rmse: 2.26333	valid_1's rmse: 2.42525
# [500]	training's rmse: 2.23025	valid_1's rmse: 2.38866
# [600]	training's rmse: 2.2049	valid_1's rmse: 2.37104
# [700]	training's rmse: 2.18	valid_1's rmse: 2.35192
# [800]	training's rmse: 2.16154	valid_1's rmse: 2.35106
# Early stopping, best iteration is:
# [756]	training's rmse: 2.1693	valid_1's rmse: 2.3456
# starting: WI_2 FOODS_2
# [LightGBM] [Info] Total Bins 3776
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score 0.344394
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 3.04652	valid_1's rmse: 5.02091
# [200]	training's rmse: 2.72099	valid_1's rmse: 4.17903
# [300]	training's rmse: 2.62874	valid_1's rmse: 3.80863
# [400]	training's rmse: 2.56915	valid_1's rmse: 3.61618
# [500]	training's rmse: 2.53016	valid_1's rmse: 3.51806
# [600]	training's rmse: 2.49059	valid_1's rmse: 3.46453
# [700]	training's rmse: 2.45947	valid_1's rmse: 3.43974
# [800]	training's rmse: 2.42611	valid_1's rmse: 3.42666
# Early stopping, best iteration is:
# [799]	training's rmse: 2.42628	valid_1's rmse: 3.42655
# starting: WI_2 FOODS_3
# [LightGBM] [Info] Total Bins 4259
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.685090
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 4.49553	valid_1's rmse: 5.17226
# [200]	training's rmse: 4.11111	valid_1's rmse: 4.67481
# [300]	training's rmse: 4.01393	valid_1's rmse: 4.54923
# [400]	training's rmse: 3.963	valid_1's rmse: 4.5143
# [500]	training's rmse: 3.93239	valid_1's rmse: 4.498
# [600]	training's rmse: 3.89739	valid_1's rmse: 4.47916
# [700]	training's rmse: 3.86314	valid_1's rmse: 4.46843
# [800]	training's rmse: 3.83841	valid_1's rmse: 4.45929
# [900]	training's rmse: 3.81059	valid_1's rmse: 4.45492
# [1000]	training's rmse: 3.78344	valid_1's rmse: 4.44957
# [1100]	training's rmse: 3.75651	valid_1's rmse: 4.44063
# [1200]	training's rmse: 3.73322	valid_1's rmse: 4.43292
# [1300]	training's rmse: 3.70894	valid_1's rmse: 4.42657
# Early stopping, best iteration is:
# [1348]	training's rmse: 3.69832	valid_1's rmse: 4.42607
# starting: WI_3 HOBBIES_1
# [LightGBM] [Info] Total Bins 3414
# [LightGBM] [Info] Number of data points in the train set: 784160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.626589
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.50196	valid_1's rmse: 1.58829
# [200]	training's rmse: 1.45624	valid_1's rmse: 1.55757
# [300]	training's rmse: 1.43784	valid_1's rmse: 1.55254
# Early stopping, best iteration is:
# [334]	training's rmse: 1.43372	valid_1's rmse: 1.55207
# starting: WI_3 HOBBIES_2
# [LightGBM] [Info] Total Bins 2580
# [LightGBM] [Info] Number of data points in the train set: 280865, number of used features: 30
# [LightGBM] [Info] Start training from score -1.955139
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.585747	valid_1's rmse: 0.622966
# [200]	training's rmse: 0.566083	valid_1's rmse: 0.619344
# [300]	training's rmse: 0.556097	valid_1's rmse: 0.618753
# [400]	training's rmse: 0.547552	valid_1's rmse: 0.618079
# Early stopping, best iteration is:
# [440]	training's rmse: 0.545329	valid_1's rmse: 0.617684
# starting: WI_3 HOUSEHOLD_1
# [LightGBM] [Info] Total Bins 3569
# [LightGBM] [Info] Number of data points in the train set: 1002820, number of used features: 30
# [LightGBM] [Info] Start training from score -0.003807
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 1.7671	valid_1's rmse: 1.79786
# [200]	training's rmse: 1.60668	valid_1's rmse: 1.64837
# [300]	training's rmse: 1.5609	valid_1's rmse: 1.61648
# [400]	training's rmse: 1.53708	valid_1's rmse: 1.60504
# [500]	training's rmse: 1.524	valid_1's rmse: 1.60028
# [600]	training's rmse: 1.51213	valid_1's rmse: 1.59739
# [700]	training's rmse: 1.50304	valid_1's rmse: 1.59639
# [800]	training's rmse: 1.49571	valid_1's rmse: 1.59607
# Early stopping, best iteration is:
# [751]	training's rmse: 1.49898	valid_1's rmse: 1.59594
# starting: WI_3 HOUSEHOLD_2
# [LightGBM] [Info] Total Bins 2968
# [LightGBM] [Info] Number of data points in the train set: 970775, number of used features: 30
# [LightGBM] [Info] Start training from score -1.539504
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.546738	valid_1's rmse: 0.760805
# [200]	training's rmse: 0.531377	valid_1's rmse: 0.732656
# [300]	training's rmse: 0.526022	valid_1's rmse: 0.725454
# [400]	training's rmse: 0.523204	valid_1's rmse: 0.723966
# Early stopping, best iteration is:
# [400]	training's rmse: 0.523204	valid_1's rmse: 0.723966
# starting: WI_3 FOODS_1
# [LightGBM] [Info] Total Bins 3328
# [LightGBM] [Info] Number of data points in the train set: 407160, number of used features: 30
# [LightGBM] [Info] Start training from score -0.037434
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.05228	valid_1's rmse: 2.16023
# [200]	training's rmse: 1.86408	valid_1's rmse: 2.00868
# [300]	training's rmse: 1.79948	valid_1's rmse: 1.9756
# [400]	training's rmse: 1.75797	valid_1's rmse: 1.96219
# Early stopping, best iteration is:
# [415]	training's rmse: 1.75349	valid_1's rmse: 1.95956
# starting: WI_3 FOODS_2
# [LightGBM] [Info] Total Bins 3605
# [LightGBM] [Info] Number of data points in the train set: 750230, number of used features: 30
# [LightGBM] [Info] Start training from score 0.057821
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 2.04294	valid_1's rmse: 2.1299
# [200]	training's rmse: 1.82454	valid_1's rmse: 1.93382
# [300]	training's rmse: 1.76384	valid_1's rmse: 1.88687
# [400]	training's rmse: 1.7335	valid_1's rmse: 1.87749
# [500]	training's rmse: 1.71615	valid_1's rmse: 1.87003
# [600]	training's rmse: 1.70285	valid_1's rmse: 1.86089
# [700]	training's rmse: 1.69077	valid_1's rmse: 1.85416
# Early stopping, best iteration is:
# [700]	training's rmse: 1.69077	valid_1's rmse: 1.85416
# starting: WI_3 FOODS_3
# [LightGBM] [Info] Total Bins 4341
# [LightGBM] [Info] Number of data points in the train set: 1551355, number of used features: 30
# [LightGBM] [Info] Start training from score 0.802959
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 4.90618	valid_1's rmse: 4.14774
# [200]	training's rmse: 4.21521	valid_1's rmse: 3.39187
# [300]	training's rmse: 4.00954	valid_1's rmse: 3.20682
# [400]	training's rmse: 3.91151	valid_1's rmse: 3.14849
# [500]	training's rmse: 3.85943	valid_1's rmse: 3.12274
# [600]	training's rmse: 3.81136	valid_1's rmse: 3.10833
# [700]	training's rmse: 3.76133	valid_1's rmse: 3.0875
# [800]	training's rmse: 3.73064	valid_1's rmse: 3.08
# Early stopping, best iteration is:
# [835]	training's rmse: 3.72075	valid_1's rmse: 3.07627
