# %%
import numpy as np
import pandas as pd
import numpy.linalg as alg
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# ### A. Load the Data

# %%
data = pd.read_csv('/Users/distant_spring/Documents/MATH5473/homework1/city_distance.csv')

print(data)
# Out:
#    Beijing  Shanghai  HongKong   Tokyo  London  Berlin   Paris
# 0      0.0    1070.5    1973.7  2099.5  8138.1  7353.6  8213.6
# 1   1070.5       0.0    1227.8  1767.2  9161.3  8395.5  9216.7
# 2   1973.7    1227.8       0.0  2887.8  9626.0  8751.1  9629.0
# 3   2099.5    1767.2    2887.8     0.0  9561.7  8918.4  8754.4
# 4   8138.1    9161.3    9626.0  9561.7     0.0   932.1   342.7
# 5   7353.6    8395.5    8751.1  8918.4   932.1     0.0   878.1
# 6   8213.6    9216.7    9629.0  8754.4   342.7   878.1     0.0

# %%
Data = np.array(data)
n = len(Data)
cities = np.array(data.columns)

# %% [markdown]
# ### B. My Own MDS

# %%
def mds(D, dim=[]):
    H = -np.ones((n, n))/n
    H = -H.dot(D ** 2).dot(H)/2
    evals, evecs = alg.eigh(H)

    # Sort by eigenvalu in descending order
    idx = np.argsort(evals)[::-1]
    evals = evals[idx]
    evecs = evecs[:, idx]

    #Compute the coordinates using positive eigenvalued components only
    w, = np.where(evals > 0)
    if dim!=[]:
        arr = evals
        w = arr.argsort()[-dim:][::-1]
    if np.any(evals[w]<0):
        print('Error: Not enough positive eigenvalues for the selected dim.')
        return []
    L = np.diag(np.sqrt(evals[w]))
    V = evecs[:, w]
    Y = V.dot(L)
    return Y, evals, evecs

# %%
X2, eigen_values, eigen_vectors = mds(Data, dim=2)

# %% [markdown]
# ### D. Plot Normalized Eigenvalues

# %%
total = np.sum(eigen_values)
normed_eigen_values = eigen_values/total
print("Eigenvalues are:\n",eigen_values)
print("Normed Eigenvalues are:\n", normed_eigen_values)
# Out:
# Eigenvalues are:
#  [ 1.64476165e-08  1.04205370e-24  0.00000000e+00 -1.61868018e-56
#  -3.65918029e-09 -3.14148877e-08 -1.37266862e+08]
# Normed Eigenvalues are:
#  [-1.19822193e-16 -7.59144405e-33 -0.00000000e+00  1.17922138e-64
#   2.66574193e-17  2.28859954e-16  1.00000000e+00]

# %% [markdown]
# Yes, there are some negative eigenvalues.

# %%
plt.figure()
plt.plot(range(n), normed_eigen_values)
plt.show()

# %% [markdown]
# ### E. Scatter plot of cities

# %%
plt.figure()
colors = ['navy', 'turquoise', 'darkorange']
for i in range(n):
    plt.scatter(X2[i, 0], X2[i, 1], alpha=.8, label=cities[i])
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('MDS of City dataset')
plt.show()

# %% [markdown]
# By observation, we can see that the figure basically reflects the position relationship between eastern Asian cities like Beijing and Hong Kong. And the remaining western European cities lie far away from them.
