# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import math
import pandas as pd
from torch import nn,optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
def fw2(x):
    maximum = max(map(max,x))
    p = np.where(x == maximum)
    return p

# %%
####Define function for NN
def loss_batch(model, loss_func, xb, yb):
    loss = loss_func(model(xb.float()), yb)
    return loss.item(), len(xb)

# %%
####Define the NN1 class
class NeuralNetwork1(nn.Module):
    def __init__(self,N_fetures):
        super(NeuralNetwork1, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(N_fetures,32),
            nn.ReLU(),
            nn.Linear(32,1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
####Define the NN2 class
class NeuralNetwork2(nn.Module):
    def __init__(self,N_fetures):
        super(NeuralNetwork2, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(N_fetures,32),
            nn.ReLU(),
            nn.Linear(32,16),
            nn.ReLU() ,
            nn.Linear(16,1)
        )
        
    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
####Define the NN3 class
class NeuralNetwork3(nn.Module):
    def __init__(self,N_fetures):
        super(NeuralNetwork3, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(N_fetures,32),
            nn.ReLU(),
            nn.Linear(32,16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8,1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
####Define the NN4 class
class NeuralNetwork4(nn.Module):
    def __init__(self,N_fetures):
        super(NeuralNetwork4, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(N_fetures,32),
            nn.ReLU(),
            nn.Linear(32,16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8,4),
            nn.ReLU(),
            nn.Linear(4,1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %% [markdown]
# <!--
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Using cpu device
# 0
# NN4 R2 : -0.00022611363997193656
# Using cpu device
# 1
# NN4 R2 : -0.05377958635620095
# Using cpu device
# 2
# NN4 R2 : -0.009474466070104937
# Using cpu device
# 3
# NN4 R2 : -0.0022956953751274156
# Using cpu device
# 4
# NN4 R2 : 0.003056818349816748
# Using cpu device
# 5
# NN4 R2 : 0.0007864345033548048
# Using cpu device
# 6
# NN4 R2 : -0.001177082699865828
# Using cpu device
# 7
# NN4 R2 : -0.001608801189491249
# Using cpu device
# 8
# NN4 R2 : 0.0016500460421998708
# Using cpu device
# 9
# NN4 R2 : -0.00046171620390866863
# Using cpu device
# 10
# NN4 R2 : -0.00018992870717160493
# Using cpu device
# 11
# NN4 R2 : 0.0030693149074336734
# Using cpu device
# 12
# NN4 R2 : -0.0008183626833284663
# Using cpu device
# 13
# NN4 R2 : 0.0001758732913781369
# Using cpu device
# 14
# NN4 R2 : 0.0014722104508547718
# Using cpu device
# 15
# NN4 R2 : 0.0026783973504134195
# Using cpu device
# 16
# NN4 R2 : -0.014641351025415084
# Using cpu device
# 17
# NN4 R2 : -0.025728017779803602
# Using cpu device
# 18
# NN4 R2 : -0.00022894538539808273
# Using cpu device
# 19
# NN4 R2 : -0.0011170102752684485
# Using cpu device
# 20
# NN4 R2 : 0.0028015656672198963
# Using cpu device
# 21
# NN4 R2 : 0.001146612809426406
# Using cpu device
# 22
# NN4 R2 : 0.0002053394838993361
# Using cpu device
# 23
# NN4 R2 : 0.0004947008895551663
# Using cpu device
# 24
# NN4 R2 : 0.00023028181460871266
# Using cpu device
# 25
# NN4 R2 : 2.6740027314953174e-05
# Using cpu device
#
# -->

# %%
####Define the NN5 class
class NeuralNetwork5(nn.Module):
    def __init__(self,N_fetures):
        super(NeuralNetwork5, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(N_fetures,32),
            nn.ReLU(),
            nn.Linear(32,16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8,4),
            nn.ReLU(),
            nn.Linear(4,2),
            nn.ReLU(),
            nn.Linear(2,1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
import string
import os
import pandas as pd
import datetime
import numpy as np
import statsmodels.api as sm
import math
from scipy.linalg import svd
import scipy.linalg as la
import scipy.sparse.linalg as sla

# %%
pathY =  '../input/data-cleaned/Y_cleaned.csv'
pathX = '../input/data-cleaned/X_cleaned.csv'
pathdate = '../input/data-cleaned/Date_list.csv'

Y_all = pd.read_csv(pathY)
X_all = pd.read_csv(pathX)

Date_index = pd.read_csv(pathdate)

Date_index['DATE']=pd.to_datetime(Date_index['DATE'])

# %%
mu=0.2;
tol=1e-10;

# %%
nums= 30
start_dates = [pd.to_datetime('1957-03-01')+pd.offsets.DateOffset(years=x) for x in range(nums) ]

# %%
r2_oos_all = np.zeros((10,len(start_dates)))
r2_is_all = np.zeros((10,len(start_dates)))

# %%
r2_oos=np.zeros(10) 
r2_is=np.zeros(10) 
modeln=0  
groups=0
nc=0

# %%
import string
import os

import pandas as pd
import datetime
import numpy as np
import statsmodels.api as sm
import math
from scipy.linalg import svd
from sklearn import ensemble
import scipy.linalg as la
import scipy.sparse.linalg as sla
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from time import time
from sklearn import metrics
##import mlsauce as ms
import torch
from torch import nn,optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
import multiprocessing as mp

# %%
for m in range(len(start_dates)):

    start_date = start_dates[m]

    end_date =  start_date + pd.offsets.DateOffset(years=18)

    ind_training = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytrain = Y_all[ind_training]

    xtrain = X_all[ind_training]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=12)

    ind_vali = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytest = Y_all[ind_vali]
    xtest= X_all[ind_vali]

    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=1)
    ind_test = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)
    yoos = Y_all[ind_test]
    xoos= X_all[ind_test]

    ytrain_demean= ytrain - np.mean(ytrain);
    ytest_demean=ytest-np.mean(ytest);
    mtrain=np.mean(ytrain);
    mtest=np.mean(ytest);

    sd=np.zeros(len(xtrain.columns)) 
    for i in range(len(xtrain.columns)):
        
        s=np.std(xtrain.iloc[:,[i]])
        colnames = xtrain.columns
        if s.values > 0:
            colname = colnames[i]
            xtrain.loc[:,colname]=xtrain[colname]/s.values
            xtest.loc[:,colname]=xtest.loc[:,colname]/s.values
            xoos.loc[:,colname]=xoos.loc[:,colname]/s.values
            sd[i]=s.values



    r2_oos=np.zeros((7,1))
    r2_is=np.zeros((7,1))

    nump = xtrain.shape[1]
    lamv = np.arange(10,nump,50)
    ne=100

    lamc = [2,4,8,16,32]

    r = np.zeros((len(lamv),len(lamc),3))

    for n1 in range(len(lamv)):
        nf=lamv[n1]
        for n2 in range(len(lamc)):
            nc = lamc[n2]
            clf = ensemble.RandomForestRegressor(n_estimators = ne,max_features = nf,max_depth= nc)

            clffit = clf.fit(xtrain,np.ravel(ytrain))
            yhatbig1 = clffit.predict(xtest)
            r[n1,n2,0]=1 - np.linalg.norm(yhatbig1-ytest['RET'])**2 / np.linalg.norm((ytest['RET']-mtrain.values))**2
            yhatbig1= clffit.predict(xoos)
            r[n1,n2,1]=1-np.linalg.norm((yhatbig1-yoos['RET']))**2/np.linalg.norm((yoos['RET']-mtrain.values))**2
            yhatbig1= clffit.predict(xtrain)
            r[n1,n2,2]=1-np.linalg.norm((yhatbig1-ytrain['RET']))**2/np.linalg.norm((ytrain['RET']-mtrain.values))**2

    fw_2 =fw2(r[:,:,0])
    r2_oos[0]=r[fw_2[0][0],fw_2[1][0],1]
    r2_is[0]=r[fw_2[0][0],fw_2[1][0],2]
    print('RF R2 : '+np.str0(r2_oos[0]) )

# %% [markdown]
# <!--
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.13271959]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.14338958]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.05179754]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.02279436]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.01987781]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.03199525]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.02574668]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.00046852]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.00368279]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.0220791]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.02591185]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.0089929]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.00014485]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00342748]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.0063474]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00532953]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.02578498]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.01260595]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00553973]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00099103]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00205908]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.0063894]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.01550149]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00461359]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.00249316]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.08281458]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [0.00071054]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00738733]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00175881]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# RF R2 : [-0.00799493]
# -->

# %%
for m in range(len(start_dates)):

    start_date = start_dates[m]

    end_date =  start_date + pd.offsets.DateOffset(years=18)

    ind_training = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytrain = Y_all[ind_training]

    xtrain = X_all[ind_training]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=12)

    ind_vali = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytest = Y_all[ind_vali]
    xtest= X_all[ind_vali]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=1)
    ind_test = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)
  
    yoos = Y_all[ind_test]
    xoos= X_all[ind_test]

    ytrain_demean= ytrain - np.mean(ytrain);
    ytest_demean=ytest-np.mean(ytest);
    mtrain=np.mean(ytrain);
    mtest=np.mean(ytest);

    sd=np.zeros(len(xtrain.columns)) 
    for i in range(len(xtrain.columns)):
        
        s=np.std(xtrain.iloc[:,[i]])
        colnames = xtrain.columns
        if s.values > 0:
            colname = colnames[i]
            xtrain.loc[:,colname]=xtrain[colname]/s.values
            xtest.loc[:,colname]=xtest.loc[:,colname]/s.values
            xoos.loc[:,colname]=xoos.loc[:,colname]/s.values
            sd[i]=s.values




    lamv=np.arange(-1,0,0.2)

    r=np.zeros((len(lamv),3))

    for n1 in range(len(lamv)):
        lr=10**lamv[n1]
        alpha=2
        ne=50
        clf = ensemble.GradientBoostingRegressor(loss = 'ls',learning_rate =lr,n_estimators = ne,criterion = 'friedman_mse',max_depth = 2)
        clffit = clf.fit(xtrain,np.ravel(ytrain))
        yhatbig1 = clffit.predict(xtest)
        r[n1,0]=1 - np.linalg.norm(yhatbig1-ytest['RET'])**2 / np.linalg.norm((ytest['RET']-mtrain.values))**2
        yhatbig1= clffit.predict(xoos)
        r[n1,1]=1-np.linalg.norm((yhatbig1-yoos['RET']))**2/np.linalg.norm((yoos['RET']-mtrain.values))**2
        yhatbig1= clffit.predict(xtrain)
        r[n1,2]=1-np.linalg.norm((yhatbig1-ytrain['RET']))**2/np.linalg.norm((ytrain['RET']-mtrain.values))**2




    r2_oos[1]=r[np.argmax(r[:,0]),1]
    r2_is[1]=r[np.argmax(r[:,0]),2]
    print(m)
    print('GBRT R2 : '+np.str0(r2_oos[1]) )

# %% [markdown]
# <!--
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 0
# GBRT R2 : [-1.23591571]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 1
# GBRT R2 : [-1.30592077]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 2
# GBRT R2 : [-0.70277011]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 3
# GBRT R2 : [-1.39193854]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 4
# GBRT R2 : [-0.82385065]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 5
# GBRT R2 : [-0.53231284]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 6
# GBRT R2 : [-0.53452523]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 7
# GBRT R2 : [-0.31013416]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 8
# GBRT R2 : [-0.33799314]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 9
# GBRT R2 : [-1.29686497]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 10
# GBRT R2 : [-1.49830773]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 11
# GBRT R2 : [-0.49066309]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 12
# GBRT R2 : [-0.17290391]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 13
# GBRT R2 : [-0.48912981]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 14
# GBRT R2 : [-0.4726671]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 15
# GBRT R2 : [-0.83271303]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 16
# GBRT R2 : [-1.13676254]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 17
# GBRT R2 : [-0.27573887]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 18
# GBRT R2 : [-0.31315352]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 19
# GBRT R2 : [-0.06738133]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 20
# GBRT R2 : [-0.13502839]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 21
# GBRT R2 : [-0.03672977]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 22
# GBRT R2 : [0.01056533]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 23
# GBRT R2 : [-0.02792768]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 24
# GBRT R2 : [-0.00688404]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 25
# GBRT R2 : [-1.64887086]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 26
# GBRT R2 : [-0.06150723]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 27
# GBRT R2 : [-0.02366473]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 28
# GBRT R2 : [-0.02387094]
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 29
# GBRT R2 : [-0.05694818]
#
# -->

# %%
for m in range(len(start_dates)):

    start_date = start_dates[m]

    end_date =  start_date + pd.offsets.DateOffset(years=18)

    ind_training = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytrain = Y_all[ind_training]

    xtrain = X_all[ind_training]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=12)

    ind_vali = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytest = Y_all[ind_vali]
    xtest= X_all[ind_vali]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=1)
    ind_test = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)
    yoos = Y_all[ind_test]
    xoos= X_all[ind_test]

    ytrain_demean= ytrain - np.mean(ytrain);
    ytest_demean=ytest-np.mean(ytest);
    mtrain=np.mean(ytrain);
    mtest=np.mean(ytest);

    sd=np.zeros(len(xtrain.columns))
    for i in range(len(xtrain.columns)):
        
        s=np.std(xtrain.iloc[:,[i]])
        colnames = xtrain.columns
        if s.values > 0:
            colname = colnames[i]
            xtrain.loc[:,colname]=xtrain[colname]/s.values
            xtest.loc[:,colname]=xtest.loc[:,colname]/s.values
            xoos.loc[:,colname]=xoos.loc[:,colname]/s.values
            sd[i]=s.values


    xtrain= torch.tensor(np.array(xtrain))
    ytrain = torch.tensor(np.array(ytrain))
    xtest = torch.tensor(np.array(xtest))
    ytest = torch.tensor(np.array(ytest))
    xoos = torch.tensor(np.array(xoos))
    yoos = torch.tensor(np.array(yoos))


    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print('Using {} device'.format(device))



    N_fetures = xtrain.shape[1]
    criterion = nn.MSELoss()



    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    xtest = xtest.to(device)
    ytest = ytest.to(device)

    criterion = criterion.to(device)


    train_ds = TensorDataset(xtrain, ytrain)
    test_ds = TensorDataset(xtest, ytest)
    oos_ds = TensorDataset(xoos, yoos)

    lamv=np.arange(-3,-2,0.02)

    r=np.zeros((len(lamv),3))


    for n1 in range(len(lamv)):
        lr=10**lamv[n1]
        bs = 10000
        epochs = 100
        train_dl= DataLoader(train_ds,bs)
        model = NeuralNetwork1(N_fetures)
        model = model.to(device)

        optimizer =  optim.Adam(model.parameters(),lr)

        for epoch in range(epochs):
            for xb,yb in train_dl:
                y_pred = model(xb.float())
                train_loss = criterion(y_pred, yb.float())
                optimizer.zero_grad()
                train_loss.backward()
                optimizer.step()

        with torch.no_grad():
            losses, nums =loss_batch(model,criterion,xtest,ytest)
            test_loss = losses*nums

        r[n1,0]=1 - test_loss/ np.linalg.norm((ytest-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xoos,yoos)
            oos_loss = losses*nums
        r[n1,1]=1 - oos_loss/ np.linalg.norm((yoos-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtrain,ytrain)
            train_loss = np.sum(np.multiply(losses, nums))
        r[n1,2]=1 - train_loss/ np.linalg.norm((ytrain-mtrain.values))**2




    r2_oos[2]=r[np.argmax(r[:,0]),1]
    r2_is[2]=r[np.argmax(r[:,0]),2]
    print('NN1 R2 : '+np.str0(r2_oos[2]) )

# %% [markdown]
# <!--
# Using cpu device
# 0
# NN1 R2 : -4.029353161545772
# Using cpu device
# 1
# NN1 R2 : -11.530344078983633
# Using cpu device
# 2
# NN1 R2 : -26.9534388180104
# Using cpu device
# 3
# NN1 R2 : -138.83922417605496
# Using cpu device
# 4
# NN1 R2 : -14.395630366313785
# Using cpu device
# 5
# NN1 R2 : -51.81115580183743
# Using cpu device
# 6
# NN1 R2 : -75.28130020848855
# Using cpu device
# 7
# NN1 R2 : -17.974906672621668
# Using cpu device
# 8
# NN1 R2 : -3985.064948716276
# Using cpu device
# 9
# NN1 R2 : -960.5558533699797
# Using cpu device
# 10
# NN1 R2 : -2.0143590984635154
# Using cpu device
# 11
# NN1 R2 : -12.134885214871224
# Using cpu device
# 12
# NN1 R2 : -2.949283227172156
# Using cpu device
# 13
# NN1 R2 : -1.992940143881273
# Using cpu device
# 14
# NN1 R2 : -4.221121537465156
# Using cpu device
# 15
# NN1 R2 : -4.031549750317858
# Using cpu device
# 16
# NN1 R2 : -1.57402491554965
# Using cpu device
# 17
# NN1 R2 : -2.625096353308211
# Using cpu device
# 18
# NN1 R2 : -0.9980227448727088
# Using cpu device
# 19
# NN1 R2 : -1.354643263151544
# Using cpu device
# 20
# NN1 R2 : -1.4381185079116339
# Using cpu device
# 21
# NN1 R2 : -0.4977500323805877
# Using cpu device
# 22
# NN1 R2 : -0.1642892013175885
# Using cpu device
# 23
# NN1 R2 : 0.0006378542867538917
# Using cpu device
# 24
# NN1 R2 : -0.03967598342306644
# Using cpu device
# 25
# NN1 R2 : -0.16783858197983492
# Using cpu device
#
#
#
#
# Using cpu device
# 0
# NN1 R2 : -51.13257674757937
# Using cpu device
# 1
# NN1 R2 : -1.9858679751681136
# Using cpu device
# 2
# NN1 R2 : -9.313504604774055
# Using cpu device
# 3
# NN1 R2 : -384.7118334850046
# Using cpu device
# 4
# NN1 R2 : -51.35233308124906
# Using cpu device
# 5
# NN1 R2 : -76.76569899981202
# Using cpu device
# 6
# NN1 R2 : -37.239301512997216
# Using cpu device
# 7
# NN1 R2 : -15.392719402582578
# Using cpu device
# 8
# NN1 R2 : -563.5877570964418
# Using cpu device
# 9
# NN1 R2 : -238.4701490488059
# Using cpu device
# 10
# NN1 R2 : -24.387717275087798
# Using cpu device
# 11
# NN1 R2 : -6.0418785609068575
# Using cpu device
# 12
# NN1 R2 : -5.547575422052928
# Using cpu device
# 13
# NN1 R2 : -5.026688352820187
# Using cpu device
# 14
# NN1 R2 : -8.537080682474265
# Using cpu device
# 15
# NN1 R2 : -2.621318509727932
# Using cpu device
# 16
# NN1 R2 : -1.3592111151285118
# Using cpu device
# 17
# NN1 R2 : -3.5742804978156517
# Using cpu device
# 18
# NN1 R2 : -0.7289072413920252
# Using cpu device
# 19
# NN1 R2 : -0.9559252368835132
# Using cpu device
# 20
# NN1 R2 : -1.9134417814332254
# Using cpu device
# 21
# NN1 R2 : -0.10950679112466988
# Using cpu device
# 22
# NN1 R2 : -0.08623481422347656
# Using cpu device
# 23
# NN1 R2 : -0.07530783432251531
# Using cpu device
# 24
# NN1 R2 : -0.008546934416889584
#
# -->

# %%
for m in range(len(start_dates)):

    start_date = start_dates[m]

    end_date =  start_date + pd.offsets.DateOffset(years=18)

    ind_training = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytrain = Y_all[ind_training]

    xtrain = X_all[ind_training]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=12)

    ind_vali = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytest = Y_all[ind_vali]
    xtest= X_all[ind_vali]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=1)
    ind_test = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)
    yoos = Y_all[ind_test]
    xoos= X_all[ind_test]


    ytrain_demean= ytrain - np.mean(ytrain);
    ytest_demean=ytest-np.mean(ytest);
    mtrain=np.mean(ytrain);
    mtest=np.mean(ytest);

    sd=np.zeros(len(xtrain.columns)) 
    for i in range(len(xtrain.columns)):
        
        s=np.std(xtrain.iloc[:,[i]])
        colnames = xtrain.columns
        if s.values > 0:
            colname = colnames[i]
            xtrain.loc[:,colname]=xtrain[colname]/s.values
            xtest.loc[:,colname]=xtest.loc[:,colname]/s.values
            xoos.loc[:,colname]=xoos.loc[:,colname]/s.values
            sd[i]=s.values


    xtrain= torch.tensor(np.array(xtrain))
    ytrain = torch.tensor(np.array(ytrain))
    xtest = torch.tensor(np.array(xtest))
    ytest = torch.tensor(np.array(ytest))
    xoos = torch.tensor(np.array(xoos))
    yoos = torch.tensor(np.array(yoos))


    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print('Using {} device'.format(device))


    N_fetures = xtrain.shape[1]
    criterion = nn.MSELoss()

    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    xtest = xtest.to(device)
    ytest = ytest.to(device)

    criterion = criterion.to(device)


    train_ds = TensorDataset(xtrain, ytrain)
    test_ds = TensorDataset(xtest, ytest)
    oos_ds = TensorDataset(xoos, yoos)

    lamv=np.arange(-3,-2,0.02)
  

    r=np.zeros((len(lamv),3))


    for n1 in range(len(lamv)):
        lr=10**lamv[n1]
        bs = 10000
        epochs = 100
        train_dl= DataLoader(train_ds,bs)
        model = NeuralNetwork2(N_fetures)
        optimizer =  optim.Adam(model.parameters(),lr)
        for epoch in range(epochs):
            for xb,yb in train_dl:
                y_pred = model(xb.float())
                train_loss = criterion(y_pred, yb.float())
                optimizer.zero_grad()
                train_loss.backward()
                optimizer.step()

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtest,ytest)
            test_loss = losses*nums
        r[n1,0]=1 - test_loss/ np.linalg.norm((ytest-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xoos,yoos)
            oos_loss = losses*nums
        r[n1,1]=1 - oos_loss/ np.linalg.norm((yoos-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtrain,ytrain)
            train_loss = np.sum(np.multiply(losses, nums))
        r[n1,2]=1 - train_loss/ np.linalg.norm((ytrain-mtrain.values))**2



    r2_oos[3]=r[np.argmax(r[:,0]),1]
    r2_is[3]=r[np.argmax(r[:,0]),2]
    print('NN2 R2 : '+np.str0(r2_oos[3]) )

# %% [markdown]
# <!--
# Using cpu device
# 0
# NN2 R2 : -3.0982971899242076
# Using cpu device
# 1
# NN2 R2 : -3.6220443263869297
# Using cpu device
# 2
# NN2 R2 : -19.426238937308725
# Using cpu device
# 3
# NN2 R2 : -28.58983553064395
# Using cpu device
# 4
# NN2 R2 : -1.907054185556393
# Using cpu device
# 5
# NN2 R2 : -45.69522610306176
# Using cpu device
# 6
# NN2 R2 : -14.694690477768138
# Using cpu device
# 7
# NN2 R2 : -11.124142594837867
# Using cpu device
# 8
# NN2 R2 : -766.5382631649096
# Using cpu device
# 9
# NN2 R2 : -198.71977898790539
# Using cpu device
# 10
# NN2 R2 : -91.45139061283953
# Using cpu device
# 11
# NN2 R2 : -1.5376432673276135
# Using cpu device
# 12
# NN2 R2 : -1.1397091776161887
# Using cpu device
# 13
# NN2 R2 : -1.5245483288656962
# Using cpu device
# 14
# NN2 R2 : -1.041580126761918
# Using cpu device
# 15
# NN2 R2 : -2.6957385036628163
# Using cpu device
# 16
# NN2 R2 : -0.7193964690491694
# Using cpu device
# 17
# NN2 R2 : -2.1607369398687237
# Using cpu device
# 18
# NN2 R2 : -0.35101050262505074
# Using cpu device
# 19
# NN2 R2 : -0.4073893110768625
# Using cpu device
# 20
# NN2 R2 : -0.6171514122091772
# Using cpu device
# 21
# NN2 R2 : -0.053393722994557136
# Using cpu device
# 22
# NN2 R2 : -0.07836231386299386
# Using cpu device
# 23
# NN2 R2 : -0.11547941986943067
# Using cpu device
# 24
# NN2 R2 : -0.07623751304153759
# Using cpu device
# 25
# NN2 R2 : -0.21330289300607297
# Using cpu device
# 26
# NN2 R2 : -0.030651431504435056
# Using cpu device
# 27
# NN2 R2 : -0.04635770173332121
# Using cpu device
# 28
# NN2 R2 : -0.009584019110487452
# Using cpu device
# 29
# NN2 R2 : -0.07578425749104256
# -->

# %%
for m in range(len(start_dates)):

    start_date = start_dates[m]

    end_date =  start_date + pd.offsets.DateOffset(years=18)

    ind_training = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytrain = Y_all[ind_training]

    xtrain = X_all[ind_training]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=12)

    ind_vali = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytest = Y_all[ind_vali]
    xtest= X_all[ind_vali]


    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=1)
    ind_test = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)
    yoos = Y_all[ind_test]
    xoos= X_all[ind_test]

    ytrain_demean= ytrain - np.mean(ytrain);
    ytest_demean=ytest-np.mean(ytest);
    mtrain=np.mean(ytrain);
    mtest=np.mean(ytest);

    sd=np.zeros(len(xtrain.columns)) 
    for i in range(len(xtrain.columns)):
        
        s=np.std(xtrain.iloc[:,[i]])
        colnames = xtrain.columns
        if s.values > 0:
            colname = colnames[i]
            xtrain.loc[:,colname]=xtrain[colname]/s.values
            xtest.loc[:,colname]=xtest.loc[:,colname]/s.values
            xoos.loc[:,colname]=xoos.loc[:,colname]/s.values
            sd[i]=s.values

    xtrain= torch.tensor(np.array(xtrain))
    ytrain = torch.tensor(np.array(ytrain))
    xtest = torch.tensor(np.array(xtest))
    ytest = torch.tensor(np.array(ytest))
    xoos = torch.tensor(np.array(xoos))
    yoos = torch.tensor(np.array(yoos))


    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print('Using {} device'.format(device))


    N_fetures = xtrain.shape[1]
    criterion = nn.MSELoss()


    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    xtest = xtest.to(device)
    ytest = ytest.to(device)

    criterion = criterion.to(device)


    train_ds = TensorDataset(xtrain, ytrain)
    test_ds = TensorDataset(xtest, ytest)
    oos_ds = TensorDataset(xoos, yoos)
    lamv=np.arange(-3,-2,0.02)

    r=np.zeros((len(lamv),3))



    for n1 in range(len(lamv)):
        lr=10**lamv[n1]
        bs = 10000
        epochs = 100
        train_dl= DataLoader(train_ds,bs)
        model = NeuralNetwork3(N_fetures)
        optimizer =  optim.Adam(model.parameters(),lr)
        for epoch in range(epochs):
            for xb,yb in train_dl:
                y_pred = model(xb.float())
                train_loss = criterion(y_pred, yb.float())
                optimizer.zero_grad()
                train_loss.backward()
                optimizer.step()

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtest,ytest)
            test_loss = losses*nums
        r[n1,0]=1 - test_loss/ np.linalg.norm((ytest-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xoos,yoos)
            oos_loss = losses*nums
        r[n1,1]=1 - oos_loss/ np.linalg.norm((yoos-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtrain,ytrain)
            train_loss = np.sum(np.multiply(losses, nums))
        r[n1,2]=1 - train_loss/ np.linalg.norm((ytrain-mtrain.values))**2




    r2_oos[4]=r[np.argmax(r[:,0]),1]
    r2_is[4]=r[np.argmax(r[:,0]),2]
    print(m)
    print('NN3 R2 : '+np.str0(r2_oos[4]) )

# %% [markdown]
# <!--
# Using cpu device
# 0
# NN3 R2 : -0.5416899708123579
# Using cpu device
# 1
# NN3 R2 : -0.9754139524357803
# Using cpu device
# 2
# NN3 R2 : -9.216756811768299
# Using cpu device
# 3
# NN3 R2 : -0.7155446767192688
# Using cpu device
# 4
# NN3 R2 : -0.7635830302538682
# Using cpu device
# 5
# NN3 R2 : -5.619251504002514
# Using cpu device
# 6
# NN3 R2 : -5.806864622097161
# Using cpu device
# 7
# NN3 R2 : -6.335594048390635
# Using cpu device
# 8
# NN3 R2 : -53.51021065295106
# Using cpu device
# 9
# NN3 R2 : -0.09327610286465604
# Using cpu device
# 10
# NN3 R2 : -15.173536941276915
# Using cpu device
# 11
# NN3 R2 : -0.00027641600284256107
# Using cpu device
# 12
# NN3 R2 : -0.058720741994517045
# Using cpu device
# 13
# NN3 R2 : -0.019633673399969798
# Using cpu device
# 14
# NN3 R2 : -0.3689991351412827
# Using cpu device
# 15
# NN3 R2 : -0.9372738008943078
# Using cpu device
# 16
# NN3 R2 : -0.625409975912506
# Using cpu device
# 17
# NN3 R2 : -2.031980509026965
# Using cpu device
# 18
# NN3 R2 : -0.3393476505682136
# Using cpu device
# 19
# NN3 R2 : -0.22261882688068524
# Using cpu device
# 20
# NN3 R2 : -0.3405937910314796
# Using cpu device
# 21
# NN3 R2 : 0.022079802799004122
# Using cpu device
# 22
# NN3 R2 : -0.0914003559491885
# Using cpu device
# 23
# NN3 R2 : -0.03314220844617455
# Using cpu device
#
#
# Using cpu device
# 0
# NN3 R2 : -1.0644723228563686
# Using cpu device
# 1
# NN3 R2 : -0.14357950764962824
# Using cpu device
# 2
# NN3 R2 : -16.720478286449463
# Using cpu device
# 3
# NN3 R2 : -0.06956256734382094
# Using cpu device
# 4
# NN3 R2 : -2.2330212687356616
# Using cpu device
# 5
# NN3 R2 : -11.187224387475512
# Using cpu device
# 6
# NN3 R2 : -6.77004498484623
# Using cpu device
# 7
# NN3 R2 : -0.0025896559307811984
# Using cpu device
# 8
# NN3 R2 : -2210.1922281762745
# Using cpu device
# 9
# NN3 R2 : -1.7197256740602094
# Using cpu device
# 10
# NN3 R2 : -25.521219276523823
# Using cpu device
# 11
# NN3 R2 : -4.134450969192385
# Using cpu device
# 12
# NN3 R2 : -0.3271909640835744
# Using cpu device
# 13
# NN3 R2 : -0.5039582964736724
# Using cpu device
# 15
# NN3 R2 : -1.3433506461058364
# Using cpu device
# 16
# NN3 R2 : -0.38926777408853863
# Using cpu device
# 17
# NN3 R2 : -2.0598347974686004
# Using cpu device
# 18
# NN3 R2 : -0.9049615322405102
# Using cpu device
# 19
# NN3 R2 : -0.022105471580045943
# Using cpu device
# 20
# NN3 R2 : -0.8151241845674639
# Using cpu device
# 21
# NN3 R2 : -0.01074035153322006
# Using cpu device
# 22
# NN3 R2 : -0.08697865489988432
# Using cpu device
# 23
# NN3 R2 : 0.0005006051580348503
# Using cpu device
# 24
# NN3 R2 : -0.019072197255035173
# Using cpu device
#
# -->

# %%
for m in range(len(start_dates)):

    start_date = start_dates[m]

    end_date =  start_date + pd.offsets.DateOffset(years=18)

    ind_training = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytrain = Y_all[ind_training]

    xtrain = X_all[ind_training]

    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=12)

    ind_vali = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytest = Y_all[ind_vali]
    xtest= X_all[ind_vali]

    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=1)
    ind_test = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)
    yoos = Y_all[ind_test]
    xoos= X_all[ind_test]

    ytrain_demean= ytrain - np.mean(ytrain);
    ytest_demean=ytest-np.mean(ytest);
    mtrain=np.mean(ytrain);
    mtest=np.mean(ytest);

    sd=np.zeros(len(xtrain.columns)) 
    for i in range(len(xtrain.columns)):
        
        s=np.std(xtrain.iloc[:,[i]])
        colnames = xtrain.columns
        if s.values > 0:
            colname = colnames[i]
            xtrain.loc[:,colname]=xtrain[colname]/s.values
            xtest.loc[:,colname]=xtest.loc[:,colname]/s.values
            xoos.loc[:,colname]=xoos.loc[:,colname]/s.values
            sd[i]=s.values
   
    xtrain= torch.tensor(np.array(xtrain))
    ytrain = torch.tensor(np.array(ytrain))
    xtest = torch.tensor(np.array(xtest))
    ytest = torch.tensor(np.array(ytest))
    xoos = torch.tensor(np.array(xoos))
    yoos = torch.tensor(np.array(yoos))


    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print('Using {} device'.format(device))


    N_fetures = xtrain.shape[1]
    criterion = nn.MSELoss()


    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    xtest = xtest.to(device)
    ytest = ytest.to(device)

    criterion = criterion.to(device)


    train_ds = TensorDataset(xtrain, ytrain)
    test_ds = TensorDataset(xtest, ytest)
    oos_ds = TensorDataset(xoos, yoos)

    lamv=np.arange(-3,-2,0.02)

    r=np.zeros((len(lamv),3))


    for n1 in range(len(lamv)):
        lr=10**lamv[n1]
        bs = 10000
        epochs = 100
        train_dl= DataLoader(train_ds,bs)
        model = NeuralNetwork4(N_fetures)
        optimizer =  optim.Adam(model.parameters(),lr)
        for epoch in range(epochs):
            for xb,yb in train_dl:
                y_pred = model(xb.float())
                train_loss = criterion(y_pred, yb.float())
                optimizer.zero_grad()
                train_loss.backward()
                optimizer.step()

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtest,ytest)
            test_loss = losses*nums
        r[n1,0]=1 - test_loss/ np.linalg.norm((ytest-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xoos,yoos)
            oos_loss = losses*nums
        r[n1,1]=1 - oos_loss/ np.linalg.norm((yoos-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtrain,ytrain)
            train_loss = np.sum(np.multiply(losses, nums))
        r[n1,2]=1 - train_loss/ np.linalg.norm((ytrain-mtrain.values))**2




    r2_oos[5]=r[np.argmax(r[:,0]),1]
    r2_is[5]=r[np.argmax(r[:,0]),2]
    print('NN4 R2 : '+np.str0(r2_oos[5]) )

# %% [markdown]
# <!--
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Using cpu device
# 0
# NN4 R2 : -0.00022611363997193656
# Using cpu device
# 1
# NN4 R2 : -0.05377958635620095
# Using cpu device
# 2
# NN4 R2 : -0.009474466070104937
# Using cpu device
# 3
# NN4 R2 : -0.0022956953751274156
# Using cpu device
# 4
# NN4 R2 : 0.003056818349816748
# Using cpu device
# 5
# NN4 R2 : 0.0007864345033548048
# Using cpu device
# 6
# NN4 R2 : -0.001177082699865828
# Using cpu device
# 7
# NN4 R2 : -0.001608801189491249
# Using cpu device
# 8
# NN4 R2 : 0.0016500460421998708
# Using cpu device
# 9
# NN4 R2 : -0.00046171620390866863
# Using cpu device
# 10
# NN4 R2 : -0.00018992870717160493
# Using cpu device
# 11
# NN4 R2 : 0.0030693149074336734
# Using cpu device
# 12
# NN4 R2 : -0.0008183626833284663
# Using cpu device
# 13
# NN4 R2 : 0.0001758732913781369
# Using cpu device
# 14
# NN4 R2 : 0.0014722104508547718
# Using cpu device
# 15
# NN4 R2 : 0.0026783973504134195
# Using cpu device
# 16
# NN4 R2 : -0.014641351025415084
# Using cpu device
# 17
# NN4 R2 : -0.025728017779803602
# Using cpu device
# 18
# NN4 R2 : -0.00022894538539808273
# Using cpu device
# 19
# NN4 R2 : -0.0011170102752684485
# Using cpu device
# 20
# NN4 R2 : 0.0028015656672198963
# Using cpu device
# 21
# NN4 R2 : 0.001146612809426406
# Using cpu device
# 22
# NN4 R2 : 0.0002053394838993361
# Using cpu device
# 23
# NN4 R2 : 0.0004947008895551663
# Using cpu device
# 24
# NN4 R2 : 0.00023028181460871266
# Using cpu device
# 25
# NN4 R2 : 2.6740027314953174e-05
# Using cpu device
# -->

# %%
for m in range(len(start_dates)):

    start_date = start_dates[m]

    end_date =  start_date + pd.offsets.DateOffset(years=18)

    ind_training = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytrain = Y_all[ind_training]

    xtrain = X_all[ind_training]

    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=12)

    ind_vali = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)

    ytest = Y_all[ind_vali]
    xtest= X_all[ind_vali]

    start_date =  end_date
    end_date = start_date + pd.offsets.DateOffset(years=1)
    ind_test = (start_date < Date_index['DATE']) & (Date_index['DATE'] < end_date)
    yoos = Y_all[ind_test]
    xoos= X_all[ind_test]

    ytrain_demean= ytrain - np.mean(ytrain);
    ytest_demean=ytest-np.mean(ytest);
    mtrain=np.mean(ytrain);
    mtest=np.mean(ytest);

    sd=np.zeros(len(xtrain.columns))
    for i in range(len(xtrain.columns)):
        
        s=np.std(xtrain.iloc[:,[i]])
        colnames = xtrain.columns
        if s.values > 0:
            colname = colnames[i]
            xtrain.loc[:,colname]=xtrain[colname]/s.values
            xtest.loc[:,colname]=xtest.loc[:,colname]/s.values
            xoos.loc[:,colname]=xoos.loc[:,colname]/s.values
            sd[i]=s.values

    xtrain= torch.tensor(np.array(xtrain))
    ytrain = torch.tensor(np.array(ytrain))
    xtest = torch.tensor(np.array(xtest))
    ytest = torch.tensor(np.array(ytest))
    xoos = torch.tensor(np.array(xoos))
    yoos = torch.tensor(np.array(yoos))


    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print('Using {} device'.format(device))


    N_fetures = xtrain.shape[1]
    criterion = nn.MSELoss()


    xtrain = xtrain.to(device)
    ytrain = ytrain.to(device)
    xtest = xtest.to(device)
    ytest = ytest.to(device)

    criterion = criterion.to(device)


    train_ds = TensorDataset(xtrain, ytrain)
    test_ds = TensorDataset(xtest, ytest)
    oos_ds = TensorDataset(xoos, yoos)
    lamv=np.arange(-3,-2,0.02)

    r=np.zeros((len(lamv),3))



    for n1 in range(len(lamv)):
        lr=10**lamv[n1]
        bs = 10000
        epochs = 100
        train_dl= DataLoader(train_ds,bs)
        model = NeuralNetwork5(N_fetures)
        optimizer =  optim.Adam(model.parameters(),lr)
        ###Train NN1 model
        for epoch in range(epochs):
            for xb,yb in train_dl:
                y_pred = model(xb.float())
                train_loss = criterion(y_pred, yb.float())
                optimizer.zero_grad()
                train_loss.backward()
                optimizer.step()

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtest,ytest)
            test_loss = losses*nums
        r[n1,0]=1 - test_loss/ np.linalg.norm((ytest-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xoos,yoos)
            oos_loss = losses*nums
        r[n1,1]=1 - oos_loss/ np.linalg.norm((yoos-mtrain.values))**2

        with torch.no_grad():
            losses, nums = loss_batch(model,criterion,xtrain,ytrain)
            train_loss = np.sum(np.multiply(losses, nums))
        r[n1,2]=1 - train_loss/ np.linalg.norm((ytrain-mtrain.values))**2




    r2_oos[6]=r[np.argmax(r[:,0]),1]
    r2_is[6]=r[np.argmax(r[:,0]),2]
    print('NN5 R2 : '+np.str0(r2_oos[6]) )

# %% [markdown]
# <!--
# Using cpu device
# 0
# NN5 R2 : -0.009035080967500386
# Using cpu device
# 1
# NN5 R2 : -0.0022667758255630055
# Using cpu device
# 2
# NN5 R2 : -0.00497463021996114
# Using cpu device
# 3
# NN5 R2 : -0.0024650811692998875
# Using cpu device
# 4
# NN5 R2 : 0.0030051369385607485
# Using cpu device
# 5
# NN5 R2 : -0.004165749276145769
# Using cpu device
# 6
# NN5 R2 : -9.073382544366737e-05
# Using cpu device
# 7
# NN5 R2 : -0.0009263744540664032
# Using cpu device
# 8
# NN5 R2 : 0.0017193694293363704
# Using cpu device
# 9
# NN5 R2 : -0.00043187195451488414
# Using cpu device
# 10
# NN5 R2 : -0.00018076032357239313
# Using cpu device
# 12
# NN5 R2 : -0.0009310723271005461
# Using cpu device
# 13
# NN5 R2 : 7.694299149108019e-05
# Using cpu device
# 14
# NN5 R2 : 5.97661359746926e-06
# Using cpu device
# 15
# NN5 R2 : -0.0035394028065325323
# Using cpu device
# 16
# NN5 R2 : -0.014457042902737083
# Using cpu device
# 17
# NN5 R2 : -0.025692124503103875
# Using cpu device
# 18
# NN5 R2 : -0.00022390201323196912
# Using cpu device
# 19
# NN5 R2 : -0.0007506551315847876
# Using cpu device
# 20
# NN5 R2 : -0.005098196537458133
# Using cpu device
# 21
# NN5 R2 : 0.008342381291731482
# Using cpu device
# 22
# NN5 R2 : 0.00033709052320685107
# Using cpu device
# 23
# NN5 R2 : 0.00023994680071182106
# Using cpu device
# 24
# NN5 R2 : -0.0002077005116609687
# Using cpu device
# 25
# NN5 R2 : -4.903622601526436e-06
# Using cpu device
# 26
# NN5 R2 : -0.0006828110373715557
# Using cpu device
#
#
# Using cpu device
# 0
# NN5 R2 : -0.009935510508573442
# Using cpu device
# 1
# NN5 R2 : -0.008056108315214416
# Using cpu device
# 2
# NN5 R2 : -0.009444606938212807
# Using cpu device
# 3
# NN5 R2 : -0.05606391583004977
# Using cpu device
# 4
# NN5 R2 : 0.0002165072519245692
# Using cpu device
# 5
# NN5 R2 : -0.003679636169342304
# Using cpu device
# 6
# NN5 R2 : -0.00024648213688704956
# Using cpu device
# 7
# NN5 R2 : -0.00011902648146566719
# Using cpu device
# 8
# NN5 R2 : -0.00015589248526870492
# Using cpu device
# 9
# NN5 R2 : 0.0003828652850139669
# Using cpu device
# 10
# NN5 R2 : -0.00019739953992425896
# Using cpu device
# 11
# NN5 R2 : -0.00023186263755192726
# Using cpu device
# 12
# NN5 R2 : -0.0014442889825501126
# Using cpu device
# 13
# NN5 R2 : 5.516486026246881e-05
# Using cpu device
#
# -->
