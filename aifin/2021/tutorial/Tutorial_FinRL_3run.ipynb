# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.neo_finrl.preprocessor.yahoodownloader import YahooDownloader
from finrl.neo_finrl.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.neo_finrl.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.neo_finrl.env_stock_trading.env_stocktrading_np import StockTradingEnv as StockTradingEnv_numpy
from finrl.drl_agents.stablebaselines3.models import DRLAgent
from finrl.drl_agents.rllib.models import DRLAgent as DRLAgent_rllib
from finrl.neo_finrl.data_processor import DataProcessor


from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
import ray
from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# /home/hcaoaf/.local/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %%
# from config.py start_date is a string
config.START_DATE
# Out:
# '2009-01-01'

# %%
# from config.py end_date is a string
config.END_DATE
# Out:
# '2021-10-31'

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df = YahooDownloader(start_date = '2009-01-01',
                     end_date = '2021-07-06',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (91870, 8)

# %%
print(df.shape)
# Out:
# (91870, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2008-12-31   3.070357   3.133571   3.047857   2.617247  607541200  AAPL
# 1  2008-12-31  57.110001  58.220001  57.060001  45.031918    6287200  AMGN
# 2  2008-12-31  17.969999  18.750000  17.910000  14.988304    9625600   AXP
# 3  2008-12-31  41.590000  43.049999  41.500000  32.005886    5443100    BA
# 4  2008-12-31  43.700001  45.099998  43.700001  30.925039    6277400   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %% [markdown]
# # Preprocess Data

# %%
fe = FeatureEngineer(
    use_technical_indicator=True,
    tech_indicator_list= config.TECHNICAL_INDICATORS_LIST, 
    use_vix=True,
    use_turbulence=True,
    user_defined_feature=False
)
processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3148, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'], ignore_index=True).head()
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2008-12-31  AAPL   3.070357   3.133571   3.047857   2.617247  607541200.0
# 1  2008-12-31  AMGN  57.110001  58.220001  57.060001  45.031918    6287200.0
# 2  2008-12-31   AXP  17.969999  18.750000  17.910000  14.988304    9625600.0
# 3  2008-12-31    BA  41.590000  43.049999  41.500000  32.005886    5443100.0
# 4  2008-12-31   CAT  43.700001  45.099998  43.700001  30.925039    6277400.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  2.0   0.0  2.934224  2.465861   100.0  66.666667  100.0      2.617247
# 1  2.0   0.0  2.934224  2.465861   100.0  66.666667  100.0     45.031918
# 2  2.0   0.0  2.934224  2.465861   100.0  66.666667  100.0     14.988304
# 3  2.0   0.0  2.934224  2.465861   100.0  66.666667  100.0     32.005886
# 4  2.0   0.0  2.934224  2.465861   100.0  66.666667  100.0     30.925039
#
#    close_60_sma   vix  turbulence
# 0      2.617247  40.0         0.0
# 1     45.031918  40.0         0.0
# 2     14.988304  40.0         0.0
# 3     32.005886  40.0         0.0
# 4     30.925039  40.0         0.0

# %% [markdown]
# # Design Env

# %%
train = data_split(processed_full, start='2009-01-01', end='2020-07-01')
trade = data_split(processed_full, start='2020-07-01', end='2021-07-06')
print(len(train), len(trade))
# Out:
# 83897 7337

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  289.569733
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  191.749405
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   51.604496
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   40.278057
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  117.465675
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019601  305.819486  272.941232  52.413035 -25.789812
# 2892   9040100.0  1.0  1.054352  199.805209  186.023338  53.021034 -51.499737
# 2892  17414800.0  1.0 -0.447764   55.232496   49.916929  48.097038 -50.926655
# 2892   4782100.0  1.0 -0.086659   43.965358   37.648309  48.830182 -14.417185
# 2892   6836400.0  1.0 -0.896831  120.856467  114.824139  48.159663 -69.901754
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    289.815179    282.752198  30.43   12.918769
# 2892  2.013358    192.501169    182.641771  30.43   12.918769
# 2892  8.508886     52.255362     52.718948  30.43   12.918769
# 2892  1.500723     40.380679     40.174252  30.43   12.918769
# 2892  3.847271    119.150817    121.108865  30.43   12.918769

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   90.282990
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  246.209015
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.579552
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  121.818481
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.027292   93.089462   80.517396  62.807156  107.485318
# 0    6575800.0  2.0  3.728076  238.256908  205.260963  61.279629  271.963497
# 0    3301000.0  2.0 -0.391245  111.015321   88.229334  48.504817  -66.339667
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.284937  131.887570  114.449384  52.865421   35.546933
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     84.287015     78.044629  28.620001   53.068016
# 0  46.806139    220.275944    221.376001  28.620001   53.068016
# 0   3.142448     97.765433     91.181246  28.620001   53.068016
# 0  15.932920    176.472335    155.614168  28.620001   53.068016
# 0  14.457404    120.567699    114.745772  28.620001   53.068016

# %%
config.TECHNICAL_INDICATORS_LIST
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(config.TECHNICAL_INDICATORS_LIST)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": config.TECHNICAL_INDICATORS_LIST, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
}

# build gym
e_train_gym = StockTradingEnv(df=train, **env_kwargs)

# %%
# environment for training
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Implement DRL Algorithms

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# ## Model1: A2C

# %%
model_a2c = agent.get_model(model_name='a2c')
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device

# %%
training_a2c = agent.train_model(
    model=model_a2c,
    tb_log_name='a2c',
    total_timesteps=50000
)
# Out:
# Logging to tensorboard_log/a2c/a2c_1
# ---------------------------------------
# | time/                 |             |
# |    fps                | 107         |
# |    iterations         | 100         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -0.22       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | 25.5        |
# |    reward             | -0.23112771 |
# |    std                | 1           |
# |    value_loss         | 0.47        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 112         |
# |    iterations         | 200         |
# |    time_elapsed       | 8           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0.278       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -10         |
# |    reward             | -0.93413407 |
# |    std                | 1.01        |
# |    value_loss         | 0.362       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 115       |
# |    iterations         | 300       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -187      |
# |    reward             | 4.8809414 |
# |    std                | 1.01      |
# |    value_loss         | 22.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 116       |
# |    iterations         | 400       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -11.3     |
# |    reward             | -0.655971 |
# |    std                | 1         |
# |    value_loss         | 1.18      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 117        |
# |    iterations         | 500        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.0384    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 381        |
# |    reward             | -11.614072 |
# |    std                | 1          |
# |    value_loss         | 121        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 117       |
# |    iterations         | 600       |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.187    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 178       |
# |    reward             | 0.2407914 |
# |    std                | 1         |
# |    value_loss         | 18.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 117        |
# |    iterations         | 700        |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -93.7      |
# |    reward             | -2.4994335 |
# |    std                | 1          |
# |    value_loss         | 6.07       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 118      |
# |    iterations         | 800      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | -0.0218  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 26.6     |
# |    reward             | -2.71275 |
# |    std                | 1        |
# |    value_loss         | 4.29     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 118         |
# |    iterations         | 900         |
# |    time_elapsed       | 37          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 178         |
# |    reward             | -0.14422244 |
# |    std                | 1           |
# |    value_loss         | 26.7        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 118        |
# |    iterations         | 1000       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -46.3      |
# |    reward             | -7.3262024 |
# |    std                | 1          |
# |    value_loss         | 2.19       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 118      |
# |    iterations         | 1100     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -450     |
# |    reward             | 1.827874 |
# |    std                | 1        |
# |    value_loss         | 123      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 118       |
# |    iterations         | 1200      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.332     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -114      |
# |    reward             | 0.5308636 |
# |    std                | 1         |
# |    value_loss         | 8.23      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 1300      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -53.4     |
# |    reward             | -4.134855 |
# |    std                | 1         |
# |    value_loss         | 5.95      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 1400      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.0545    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 63.3      |
# |    reward             | 1.2658975 |
# |    std                | 1         |
# |    value_loss         | 5.77      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 119      |
# |    iterations         | 1500     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0.0933   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 89       |
# |    reward             | 4.973924 |
# |    std                | 1        |
# |    value_loss         | 6.69     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 1600      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 172       |
# |    reward             | 1.0766139 |
# |    std                | 1.01      |
# |    value_loss         | 18.8      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 119      |
# |    iterations         | 1700     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0.0236   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -230     |
# |    reward             | 6.910926 |
# |    std                | 1.01     |
# |    value_loss         | 51.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 1800      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -32.5     |
# |    reward             | 1.8304265 |
# |    std                | 1         |
# |    value_loss         | 0.752     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 119         |
# |    iterations         | 1900        |
# |    time_elapsed       | 79          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -26.3       |
# |    reward             | -0.02246022 |
# |    std                | 1           |
# |    value_loss         | 2.51        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 119         |
# |    iterations         | 2000        |
# |    time_elapsed       | 83          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -12.7       |
# |    reward             | -0.80019534 |
# |    std                | 1           |
# |    value_loss         | 4           |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 119        |
# |    iterations         | 2100       |
# |    time_elapsed       | 87         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 377        |
# |    reward             | -1.3503919 |
# |    std                | 1          |
# |    value_loss         | 117        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 2200      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -504      |
# |    reward             | -4.776145 |
# |    std                | 1         |
# |    value_loss         | 332       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 2300      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -7.46e+03 |
# |    reward             | -1.759648 |
# |    std                | 1         |
# |    value_loss         | 3.09e+04  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 119        |
# |    iterations         | 2400       |
# |    time_elapsed       | 100        |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0507     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | 88.2       |
# |    reward             | 0.58613336 |
# |    std                | 1          |
# |    value_loss         | 8.96       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 2500      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.00576  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -81.7     |
# |    reward             | 0.5751109 |
# |    std                | 1.01      |
# |    value_loss         | 4.32      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 119         |
# |    iterations         | 2600        |
# |    time_elapsed       | 108         |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2599        |
# |    policy_loss        | 51.6        |
# |    reward             | -0.48510334 |
# |    std                | 1.01        |
# |    value_loss         | 4.64        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 119        |
# |    iterations         | 2700       |
# |    time_elapsed       | 112        |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | -9.23      |
# |    reward             | -2.7437978 |
# |    std                | 1.01       |
# |    value_loss         | 0.609      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 2800      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 364       |
# |    reward             | 3.3805025 |
# |    std                | 1.01      |
# |    value_loss         | 99.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 119      |
# |    iterations         | 2900     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -107     |
# |    reward             | 2.088409 |
# |    std                | 1.01     |
# |    value_loss         | 7.12     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 3000      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.00493  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -4.18     |
# |    reward             | 0.9347972 |
# |    std                | 1.01      |
# |    value_loss         | 0.253     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 3100        |
# |    time_elapsed       | 129         |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | 65.5        |
# |    reward             | -0.62072706 |
# |    std                | 1.01        |
# |    value_loss         | 3.47        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 3200       |
# |    time_elapsed       | 133        |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | 213        |
# |    reward             | -1.2614508 |
# |    std                | 1.01       |
# |    value_loss         | 57.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 3300      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.00169  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 547       |
# |    reward             | -2.211514 |
# |    std                | 1.01      |
# |    value_loss         | 239       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 3400      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 92.6      |
# |    reward             | 35.547592 |
# |    std                | 1.01      |
# |    value_loss         | 82.7      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 3500     |
# |    time_elapsed       | 145      |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0.00345  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 137      |
# |    reward             | 1.09175  |
# |    std                | 1.01     |
# |    value_loss         | 15       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 3600     |
# |    time_elapsed       | 149      |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -126     |
# |    reward             | 2.364921 |
# |    std                | 1.01     |
# |    value_loss         | 16.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 3700      |
# |    time_elapsed       | 153       |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0144   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 159       |
# |    reward             | 1.8305702 |
# |    std                | 1.01      |
# |    value_loss         | 18        |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 3800      |
# |    time_elapsed       | 158       |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -57.5     |
# |    reward             | 2.3388028 |
# |    std                | 1.01      |
# |    value_loss         | 3.03      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 3900      |
# |    time_elapsed       | 162       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -0.0299   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 178       |
# |    reward             | 2.5984478 |
# |    std                | 1.01      |
# |    value_loss         | 21.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 4000      |
# |    time_elapsed       | 166       |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -254      |
# |    reward             | 1.8285278 |
# |    std                | 1.01      |
# |    value_loss         | 57.2      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 4100        |
# |    time_elapsed       | 170         |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | -0.0532     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | 15.1        |
# |    reward             | -0.17198586 |
# |    std                | 1.02        |
# |    value_loss         | 1.72        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 4200       |
# |    time_elapsed       | 174        |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -149       |
# |    reward             | 0.37691003 |
# |    std                | 1.02       |
# |    value_loss         | 14.2       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 4300     |
# |    time_elapsed       | 178      |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -157     |
# |    reward             | 4.320617 |
# |    std                | 1.02     |
# |    value_loss         | 14       |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 4400      |
# |    time_elapsed       | 182       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 82.6      |
# |    reward             | 2.4565418 |
# |    std                | 1.02      |
# |    value_loss         | 11        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 4500       |
# |    time_elapsed       | 187        |
# |    total_timesteps    | 22500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | 422        |
# |    reward             | -1.3075458 |
# |    std                | 1.02       |
# |    value_loss         | 139        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 4600      |
# |    time_elapsed       | 191       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 223       |
# |    reward             | 6.436497  |
# |    std                | 1.02      |
# |    value_loss         | 30.1      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 4700        |
# |    time_elapsed       | 195         |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | -0.00424    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | -193        |
# |    reward             | 0.055816222 |
# |    std                | 1.02        |
# |    value_loss         | 26.1        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 4800       |
# |    time_elapsed       | 199        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -153       |
# |    reward             | -1.2409713 |
# |    std                | 1.02       |
# |    value_loss         | 15.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 4900       |
# |    time_elapsed       | 203        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -51        |
# |    reward             | 0.16114837 |
# |    std                | 1.02       |
# |    value_loss         | 2.26       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 5000       |
# |    time_elapsed       | 207        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | 80.1       |
# |    reward             | 0.96094155 |
# |    std                | 1.02       |
# |    value_loss         | 7.16       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 5100       |
# |    time_elapsed       | 211        |
# |    total_timesteps    | 25500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5099       |
# |    policy_loss        | 97.6       |
# |    reward             | -0.6523934 |
# |    std                | 1.02       |
# |    value_loss         | 17.7       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 5200     |
# |    time_elapsed       | 215      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -338     |
# |    reward             | 7.174619 |
# |    std                | 1.02     |
# |    value_loss         | 89.9     |
# ------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 6313519.21
# total_reward: 5313519.21
# total_cost: 42549.29
# total_trades: 51453
# Sharpe: 0.972
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 5300       |
# |    time_elapsed       | 220        |
# |    total_timesteps    | 26500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5299       |
# |    policy_loss        | -33.2      |
# |    reward             | 0.19445185 |
# |    std                | 1.02       |
# |    value_loss         | 0.805      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 5400        |
# |    time_elapsed       | 224         |
# |    total_timesteps    | 27000       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5399        |
# |    policy_loss        | -25         |
# |    reward             | -0.08590252 |
# |    std                | 1.03        |
# |    value_loss         | 2.07        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 5500      |
# |    time_elapsed       | 228       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | -0.0019   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -14.3     |
# |    reward             | 2.6130233 |
# |    std                | 1.03      |
# |    value_loss         | 9.34      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 5600      |
# |    time_elapsed       | 232       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -103      |
# |    reward             | 1.2896944 |
# |    std                | 1.03      |
# |    value_loss         | 7.62      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 5700       |
# |    time_elapsed       | 236        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | -237       |
# |    reward             | -5.0642457 |
# |    std                | 1.03       |
# |    value_loss         | 45.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 5800      |
# |    time_elapsed       | 240       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | -0.103    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -44.2     |
# |    reward             | 2.2533517 |
# |    std                | 1.03      |
# |    value_loss         | 6.11      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 5900       |
# |    time_elapsed       | 244        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | 32.1       |
# |    reward             | -0.3148387 |
# |    std                | 1.03       |
# |    value_loss         | 1.29       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 6000      |
# |    time_elapsed       | 249       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0.0222    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -54.8     |
# |    reward             | 0.5286448 |
# |    std                | 1.03      |
# |    value_loss         | 2.46      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 6100       |
# |    time_elapsed       | 253        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -36.8      |
# |    reward             | -2.6697717 |
# |    std                | 1.03       |
# |    value_loss         | 4.09       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 6200       |
# |    time_elapsed       | 257        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -76.9      |
# |    reward             | 0.23327005 |
# |    std                | 1.03       |
# |    value_loss         | 4.27       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 6300     |
# |    time_elapsed       | 261      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -42.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 250      |
# |    reward             | 1.933993 |
# |    std                | 1.04     |
# |    value_loss         | 52.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 6400      |
# |    time_elapsed       | 265       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | -0.0126   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 108       |
# |    reward             | 2.1442118 |
# |    std                | 1.04      |
# |    value_loss         | 8.03      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 6500       |
# |    time_elapsed       | 269        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 0.724      |
# |    reward             | -5.2531624 |
# |    std                | 1.04       |
# |    value_loss         | 3.73       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 6600       |
# |    time_elapsed       | 273        |
# |    total_timesteps    | 33000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -0.000116  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -29.5      |
# |    reward             | 0.08240909 |
# |    std                | 1.04       |
# |    value_loss         | 1.8        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 6700     |
# |    time_elapsed       | 278      |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -42.2    |
# |    explained_variance | -0.126   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -764     |
# |    reward             | -7.38872 |
# |    std                | 1.04     |
# |    value_loss         | 432      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 6800      |
# |    time_elapsed       | 282       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -147      |
# |    reward             | 1.6781449 |
# |    std                | 1.04      |
# |    value_loss         | 15.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 6900       |
# |    time_elapsed       | 286        |
# |    total_timesteps    | 34500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | -366       |
# |    reward             | -0.4420405 |
# |    std                | 1.04       |
# |    value_loss         | 104        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 7000       |
# |    time_elapsed       | 290        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 61.2       |
# |    reward             | 0.33543074 |
# |    std                | 1.03       |
# |    value_loss         | 2.55       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 7100      |
# |    time_elapsed       | 294       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 113       |
# |    reward             | 1.8580586 |
# |    std                | 1.04      |
# |    value_loss         | 8.25      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 7200       |
# |    time_elapsed       | 298        |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | -246       |
# |    reward             | 0.49294743 |
# |    std                | 1.04       |
# |    value_loss         | 45.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 7300       |
# |    time_elapsed       | 302        |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | -76.3      |
# |    reward             | 0.33050156 |
# |    std                | 1.04       |
# |    value_loss         | 15.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 7400      |
# |    time_elapsed       | 306       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -83.8     |
# |    reward             | -6.152716 |
# |    std                | 1.04      |
# |    value_loss         | 6.39      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 7500       |
# |    time_elapsed       | 311        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | 307        |
# |    reward             | -15.894705 |
# |    std                | 1.04       |
# |    value_loss         | 65.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 7600       |
# |    time_elapsed       | 315        |
# |    total_timesteps    | 38000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0.0022     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7599       |
# |    policy_loss        | -143       |
# |    reward             | 0.14089431 |
# |    std                | 1.04       |
# |    value_loss         | 10.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 7700       |
# |    time_elapsed       | 319        |
# |    total_timesteps    | 38500      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7699       |
# |    policy_loss        | -90.2      |
# |    reward             | 0.63794494 |
# |    std                | 1.04       |
# |    value_loss         | 5.46       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 7800       |
# |    time_elapsed       | 323        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -13.1      |
# |    reward             | -1.0770715 |
# |    std                | 1.04       |
# |    value_loss         | 0.678      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 7900     |
# |    time_elapsed       | 327      |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -42.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 213      |
# |    reward             | 3.072809 |
# |    std                | 1.04     |
# |    value_loss         | 38.2     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 8000      |
# |    time_elapsed       | 331       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -100      |
# |    reward             | -3.414895 |
# |    std                | 1.04      |
# |    value_loss         | 22.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 8100      |
# |    time_elapsed       | 335       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 423       |
# |    reward             | 11.893944 |
# |    std                | 1.04      |
# |    value_loss         | 117       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 8200       |
# |    time_elapsed       | 340        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | 43.7       |
# |    reward             | 0.37902406 |
# |    std                | 1.05       |
# |    value_loss         | 1.22       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 8300       |
# |    time_elapsed       | 344        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | 54.4       |
# |    reward             | -0.7222878 |
# |    std                | 1.04       |
# |    value_loss         | 2.56       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 8400       |
# |    time_elapsed       | 348        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0.146      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | -271       |
# |    reward             | -2.3078115 |
# |    std                | 1.05       |
# |    value_loss         | 42.6       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 8500     |
# |    time_elapsed       | 352      |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 72.4     |
# |    reward             | 0.753642 |
# |    std                | 1.05     |
# |    value_loss         | 2.91     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 8600        |
# |    time_elapsed       | 356         |
# |    total_timesteps    | 43000       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8599        |
# |    policy_loss        | 86.4        |
# |    reward             | -10.1936455 |
# |    std                | 1.05        |
# |    value_loss         | 19.2        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 8700      |
# |    time_elapsed       | 360       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -46.2     |
# |    reward             | 0.9506726 |
# |    std                | 1.05      |
# |    value_loss         | 2.87      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 8800      |
# |    time_elapsed       | 364       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0.0431    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | 1.22      |
# |    reward             | 0.2819813 |
# |    std                | 1.05      |
# |    value_loss         | 0.798     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 8900      |
# |    time_elapsed       | 369       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -1.83     |
# |    reward             | 2.0969887 |
# |    std                | 1.05      |
# |    value_loss         | 0.57      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 9000        |
# |    time_elapsed       | 373         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | -43         |
# |    reward             | -0.41397074 |
# |    std                | 1.05        |
# |    value_loss         | 2.11        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 9100      |
# |    time_elapsed       | 377       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | 120       |
# |    reward             | 1.0844234 |
# |    std                | 1.05      |
# |    value_loss         | 8.45      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 9200      |
# |    time_elapsed       | 381       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | 84.2      |
# |    reward             | 3.2923622 |
# |    std                | 1.05      |
# |    value_loss         | 5.43      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 9300      |
# |    time_elapsed       | 385       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | -130      |
# |    reward             | 0.6149442 |
# |    std                | 1.05      |
# |    value_loss         | 10.4      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 9400        |
# |    time_elapsed       | 389         |
# |    total_timesteps    | 47000       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9399        |
# |    policy_loss        | 184         |
# |    reward             | -0.79114133 |
# |    std                | 1.05        |
# |    value_loss         | 19.6        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 9500       |
# |    time_elapsed       | 393        |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | 91.1       |
# |    reward             | 0.17409816 |
# |    std                | 1.05       |
# |    value_loss         | 10.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 9600       |
# |    time_elapsed       | 397        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -104       |
# |    reward             | -2.2394838 |
# |    std                | 1.05       |
# |    value_loss         | 9.67       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 9700       |
# |    time_elapsed       | 402        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | 173        |
# |    reward             | 0.24198753 |
# |    std                | 1.05       |
# |    value_loss         | 23.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 9800       |
# |    time_elapsed       | 406        |
# |    total_timesteps    | 49000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9799       |
# |    policy_loss        | -62.3      |
# |    reward             | -1.3657953 |
# |    std                | 1.05       |
# |    value_loss         | 95.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 9900       |
# |    time_elapsed       | 410        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | 30.1       |
# |    reward             | 0.26089752 |
# |    std                | 1.05       |
# |    value_loss         | 0.667      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 10000     |
# |    time_elapsed       | 414       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 62        |
# |    reward             | 1.1902944 |
# |    std                | 1.05      |
# |    value_loss         | 3.4       |
# -------------------------------------

# %% [markdown]
# ## Model2: DDPG

# %%
model_ddpg = agent.get_model("ddpg")
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ddpg/ddpg_1
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 3880195.42
# total_reward: 2880195.42
# total_cost: 5213.92
# total_trades: 40421
# Sharpe: 0.690
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 71       |
# |    time_elapsed    | 162      |
# |    total_timesteps | 11572    |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 1.84e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8679     |
# |    reward          | 5.262882 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 70       |
# |    time_elapsed    | 327      |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 13.5     |
# |    critic_loss     | 17.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20251    |
# |    reward          | 5.262882 |
# ---------------------------------
# day: 2892, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 3840760.65
# total_reward: 2840760.65
# total_cost: 999.00
# total_trades: 49164
# Sharpe: 0.692
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 71       |
# |    time_elapsed    | 488      |
# |    total_timesteps | 34716    |
# | train/             |          |
# |    actor_loss      | 5.85     |
# |    critic_loss     | 2.95     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31823    |
# |    reward          | 5.262882 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 71       |
# |    time_elapsed    | 648      |
# |    total_timesteps | 46288    |
# | train/             |          |
# |    actor_loss      | -0.845   |
# |    critic_loss     | 2.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43395    |
# |    reward          | 5.262882 |
# ---------------------------------

# %% [markdown]
# ## Model3: PPO

# %%
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ppo/ppo_1
# ---------------------------------
# | time/              |          |
# |    fps             | 134      |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 0.413404 |
# ---------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 2          |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01629251 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.0415     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 6.57       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0231    |
# |    reward               | 0.93200374 |
# |    std                  | 1          |
# |    value_loss           | 11.5       |
# ----------------------------------------
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 3729366.03
# total_reward: 2729366.03
# total_cost: 352094.78
# total_trades: 80498
# Sharpe: 0.743
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 3           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016171433 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00259    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0143     |
# |    reward               | -1.130922   |
# |    std                  | 1           |
# |    value_loss           | 59.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 4           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013394774 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -4.88e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0144     |
# |    reward               | 3.0901184   |
# |    std                  | 1           |
# |    value_loss           | 72.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 128        |
# |    iterations           | 5          |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01832626 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | 0.00907    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.85       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0225    |
# |    reward               | 2.9820747  |
# |    std                  | 1          |
# |    value_loss           | 17.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 6           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015954703 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00435     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 51.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | 2.5150547   |
# |    std                  | 1.01        |
# |    value_loss           | 54.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 7           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015832342 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00674     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 44.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.017      |
# |    reward               | 0.34281516  |
# |    std                  | 1.01        |
# |    value_loss           | 61.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 8           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013978753 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.00307     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | 0.9441553   |
# |    std                  | 1.01        |
# |    value_loss           | 29.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 9          |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01662001 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.4      |
# |    explained_variance   | -0.00787   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 9.04       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0184    |
# |    reward               | 0.82618165 |
# |    std                  | 1.01       |
# |    value_loss           | 58.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 10         |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01699255 |
# |    clip_fraction        | 0.157      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.5      |
# |    explained_variance   | -0.0161    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 24.4       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0189    |
# |    reward               | 0.37845588 |
# |    std                  | 1.01       |
# |    value_loss           | 36         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 11          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019450735 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00329     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.02       |
# |    reward               | 0.08897618  |
# |    std                  | 1.01        |
# |    value_loss           | 35.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 12           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.024373122  |
# |    clip_fraction        | 0.243        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.6        |
# |    explained_variance   | -0.0303      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 10.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0244      |
# |    reward               | -0.079793654 |
# |    std                  | 1.02         |
# |    value_loss           | 18.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 13          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025857959 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.0023     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0245     |
# |    reward               | 0.49683225  |
# |    std                  | 1.02        |
# |    value_loss           | 51.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 14          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.01661379  |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.000426   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.013      |
# |    reward               | -0.04085606 |
# |    std                  | 1.02        |
# |    value_loss           | 63.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 15          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021699196 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.0263     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.3        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0132     |
# |    reward               | 3.5944345   |
# |    std                  | 1.02        |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 16          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022914069 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.0298     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.021      |
# |    reward               | 0.5415      |
# |    std                  | 1.02        |
# |    value_loss           | 69          |
# -----------------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 5253755.34
# total_reward: 4253755.34
# total_cost: 322918.38
# total_trades: 77896
# Sharpe: 0.886
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 17          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.021957334 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.000832   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 53.6        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0174     |
# |    reward               | 0.6784371   |
# |    std                  | 1.03        |
# |    value_loss           | 66.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 18          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021415528 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.0153      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0138     |
# |    reward               | 0.5537784   |
# |    std                  | 1.03        |
# |    value_loss           | 73.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 19          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.026612643 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0422      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.88        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0182     |
# |    reward               | 0.4111284   |
# |    std                  | 1.03        |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 20          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.026345681 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.0323      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0124     |
# |    reward               | -0.11408529 |
# |    std                  | 1.03        |
# |    value_loss           | 78          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 128        |
# |    iterations           | 21         |
# |    time_elapsed         | 334        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02222687 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.1      |
# |    explained_variance   | 0.0222     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 36.4       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00889   |
# |    reward               | -6.23088   |
# |    std                  | 1.03       |
# |    value_loss           | 68.9       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 22           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.014749306  |
# |    clip_fraction        | 0.152        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.1        |
# |    explained_variance   | -0.00182     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0162      |
# |    reward               | -0.012658862 |
# |    std                  | 1.04         |
# |    value_loss           | 36.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 23          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022085628 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0218      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.6        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0177     |
# |    reward               | 0.004033159 |
# |    std                  | 1.04        |
# |    value_loss           | 40.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 24          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022452231 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.00175     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0173     |
# |    reward               | 1.9319847   |
# |    std                  | 1.04        |
# |    value_loss           | 56.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 25          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.028157523 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.017       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.3        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00708    |
# |    reward               | 0.31139484  |
# |    std                  | 1.04        |
# |    value_loss           | 45.4        |
# -----------------------------------------

# %% [markdown]
# ## Model4: TD3

# %%
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# Logging to tensorboard_log/td3/td3_1
# day: 2892, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 4668520.06
# total_reward: 3668520.06
# total_cost: 1001.33
# total_trades: 52056
# Sharpe: 0.799
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 88        |
# |    time_elapsed    | 130       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 121       |
# |    critic_loss     | 2.57e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 4.3169436 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 83        |
# |    time_elapsed    | 278       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 44.6      |
# |    critic_loss     | 2.46e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 4.3169436 |
# ----------------------------------

# %% [markdown]
# ## Model5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}
model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=60000)
# Out:
# Logging to tensorboard_log/sac/sac_1
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 30       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 11572    |
# | train/             |          |
# |    actor_loss      | 1.43e+03 |
# |    critic_loss     | 561      |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -24.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11471    |
# |    reward          | 6.108671 |
# ---------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 27        |
# |    time_elapsed    | 856       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 560       |
# |    critic_loss     | 159       |
# |    ent_coef        | 0.0846    |
# |    ent_coef_loss   | -107      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 23043     |
# |    reward          | -11.12434 |
# ----------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5948680.05
# total_reward: 4948680.05
# total_cost: 18853.81
# total_trades: 53250
# Sharpe: 0.820
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 25        |
# |    time_elapsed    | 1372      |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | 259       |
# |    critic_loss     | 16.4      |
# |    ent_coef        | 0.0272    |
# |    ent_coef_loss   | -120      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 34615     |
# |    reward          | -4.493413 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 24         |
# |    time_elapsed    | 1886       |
# |    total_timesteps | 46288      |
# | train/             |            |
# |    actor_loss      | 140        |
# |    critic_loss     | 38         |
# |    ent_coef        | 0.00895    |
# |    ent_coef_loss   | -102       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 46187      |
# |    reward          | -1.8037932 |
# -----------------------------------
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4219238.86
# total_reward: 3219238.86
# total_cost: 2342.35
# total_trades: 48037
# Sharpe: 0.749
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 20          |
# |    fps             | 24          |
# |    time_elapsed    | 2402        |
# |    total_timesteps | 57860       |
# | train/             |             |
# |    actor_loss      | 80.9        |
# |    critic_loss     | 7.33        |
# |    ent_coef        | 0.00304     |
# |    ent_coef_loss   | -56.2       |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 57759       |
# |    reward          | -0.32733813 |
# ------------------------------------

# %% [markdown]
# # Trading
#
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the DDPG model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data, if current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<'2020-07-01') & (processed_full.date>='2009-01-01')]

# %%
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2893.000000
# mean       18.824245
# std         8.489311
# min         9.140000
# 25%        13.330000
# 50%        16.139999
# 75%        21.309999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34.574232
# std        43.787168
# min         0.000000
# 25%        14.966338
# 50%        24.124579
# 75%        39.162424
# max       652.503895
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 276.4528315237581

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2020-06 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(
    df = trade,
    turbulence_threshold=70,
    risk_indicator_col='vix',
    **env_kwargs
)

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   90.282990
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  246.209015
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.579552
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  121.818481
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.027292   93.089462   80.517396  62.807156  107.485318
# 0    6575800.0  2.0  3.728076  238.256908  205.260963  61.279629  271.963497
# 0    3301000.0  2.0 -0.391245  111.015321   88.229334  48.504817  -66.339667
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.284937  131.887570  114.449384  52.865421   35.546933
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     84.287015     78.044629  28.620001   53.068016
# 0  46.806139    220.275944    221.376001  28.620001   53.068016
# 0   3.142448     97.765433     91.181246  28.620001   53.068016
# 0  15.932920    176.472335    155.614168  28.620001   53.068016
# 0  14.457404    120.567699    114.745772  28.620001   53.068016

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model = trained_sac,
    environment = e_trade_gym
)
# Out:
# hit end!

# %%
print(df_account_value.shape)
print(df_actions.shape)
# Out:
# (253, 2)
# (252, 29)

# %% [markdown]
# # BackTest

# %% [markdown]
# ## BackTest Stats

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.250596
# Cumulative returns     0.251707
# Annual volatility      0.148737
# Sharpe ratio           1.584268
# Calmar ratio           2.517275
# Stability              0.885863
# Max drawdown          -0.099551
# Omega ratio            1.304797
# Sortino ratio          2.336795
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.962107
# Daily value at risk   -0.017804
# dtype: float64

# %%
# baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
    ticker='^DJI',
    start=df_account_value.loc[0,'date'],
    end=df_account_value.loc[len(df_account_value)-1,'date']
)
stats = backtest_stats(baseline_df, value_col_name='close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (253, 8)
# Annual return          0.335107
# Cumulative returns     0.336639
# Annual volatility      0.145596
# Sharpe ratio           2.066650
# Calmar ratio           3.752275
# Stability              0.946226
# Max drawdown          -0.089308
# Omega ratio            1.410677
# Sortino ratio          3.094274
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.081322
# Daily value at risk   -0.017149
# dtype: float64

# %%
print('start:', df_account_value.loc[0,'date'], 'end:',df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# start: 2020-07-01 end: 2021-07-01

# %% [markdown]
# ## BackTestPlot

# %%
print("==============Compare to DJI===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

backtest_plot(
    account_value=df_account_value,
    baseline_ticker='^DJI',
    baseline_start=df_account_value.loc[0,'date'],
    baseline_end=df_account_value.loc[len(df_account_value)-1,'date']
)
# Out:
# ==============Compare to DJI===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (253, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-07-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>25.06%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>25.171%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.874%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.58</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.52</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-9.955%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.3</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.34</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.78%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.86</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9.96</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2020-11-16</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.06</td>
#       <td>2021-01-26</td>
#       <td>2021-03-04</td>
#       <td>2021-03-22</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6.0</td>
#       <td>2021-05-10</td>
#       <td>2021-06-18</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.52</td>
#       <td>2020-07-22</td>
#       <td>2020-07-31</td>
#       <td>2020-08-10</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.53</td>
#       <td>2020-11-16</td>
#       <td>2020-11-20</td>
#       <td>2020-11-27</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# /home/hcaoaf/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py:5277: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.09%</td>
#       <td>-3.21%</td>
#       <td>2.65%</td>
#     </tr>
#   </tbody>
# </table>
# /home/hcaoaf/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py:5277: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)

# %% [markdown]
# # Second SAC Model Train & Trade & BackTest

# %% [markdown]
# Training Phrase

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=60000)
# Out:
# Logging to tensorboard_log/sac/sac_2
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 33        |
# |    time_elapsed    | 348       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 368       |
# |    critic_loss     | 52.8      |
# |    ent_coef        | 0.111     |
# |    ent_coef_loss   | -103      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 11471     |
# |    reward          | 2.6979494 |
# ----------------------------------
# day: 2892, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 2949493.44
# total_reward: 1949493.44
# total_cost: 16113.66
# total_trades: 48742
# Sharpe: 0.485
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 30        |
# |    time_elapsed    | 761       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 121       |
# |    critic_loss     | 57.6      |
# |    ent_coef        | 0.0352    |
# |    ent_coef_loss   | -138      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 23043     |
# |    reward          | 6.1937513 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 27        |
# |    time_elapsed    | 1274      |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | 45.6      |
# |    critic_loss     | 68.5      |
# |    ent_coef        | 0.0113    |
# |    ent_coef_loss   | -144      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 34615     |
# |    reward          | 7.5889535 |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 25       |
# |    time_elapsed    | 1786     |
# |    total_timesteps | 46288    |
# | train/             |          |
# |    actor_loss      | 25.6     |
# |    critic_loss     | 7.2      |
# |    ent_coef        | 0.00379  |
# |    ent_coef_loss   | -98.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46187    |
# |    reward          | 7.128638 |
# ---------------------------------
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 2872462.84
# total_reward: 1872462.84
# total_cost: 3684.32
# total_trades: 36953
# Sharpe: 0.508
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 25       |
# |    time_elapsed    | 2300     |
# |    total_timesteps | 57860    |
# | train/             |          |
# |    actor_loss      | 16.8     |
# |    critic_loss     | 3.28     |
# |    ent_coef        | 0.00175  |
# |    ent_coef_loss   | -9.61    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57759    |
# |    reward          | 5.563793 |
# ---------------------------------

# %% [markdown]
# Trading phrase

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym)
# Out:
# hit end!

# %% [markdown]
# BackTest Phrase

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# perf_stats_all.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.409532
# Cumulative returns     0.411453
# Annual volatility      0.149417
# Sharpe ratio           2.382402
# Calmar ratio           5.045008
# Stability              0.959442
# Max drawdown          -0.081176
# Omega ratio            1.494658
# Sortino ratio          3.689053
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.246610
# Daily value at risk   -0.017412
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (253, 8)
# Annual return          0.335107
# Cumulative returns     0.336639
# Annual volatility      0.145596
# Sharpe ratio           2.066650
# Calmar ratio           3.752275
# Stability              0.946226
# Max drawdown          -0.089308
# Omega ratio            1.410677
# Sortino ratio          3.094274
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.081322
# Daily value at risk   -0.017149
# dtype: float64

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (253, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-07-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>40.953%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>41.145%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.942%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.38</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>5.05</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.118%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.49</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.69</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.25</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.741%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.09</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.89</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.12</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2020-11-16</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.88</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.83</td>
#       <td>2021-02-24</td>
#       <td>2021-02-26</td>
#       <td>2021-03-10</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.75</td>
#       <td>2021-01-13</td>
#       <td>2021-01-29</td>
#       <td>2021-02-04</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.7</td>
#       <td>2021-05-10</td>
#       <td>2021-05-12</td>
#       <td>2021-05-27</td>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table>
# /home/hcaoaf/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py:5277: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.14%</td>
#       <td>-3.09%</td>
#       <td>3.52%</td>
#     </tr>
#   </tbody>
# </table>
# /home/hcaoaf/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py:5277: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)

# %% [markdown]
# # Third SAC Model Train & Trade & BackTest

# %% [markdown]
# Training Phrase

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=60000)
# Out:
# Logging to tensorboard_log/sac/sac_3
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 22         |
# |    time_elapsed    | 509        |
# |    total_timesteps | 11572      |
# | train/             |            |
# |    actor_loss      | 646        |
# |    critic_loss     | 1.22e+03   |
# |    ent_coef        | 0.14       |
# |    ent_coef_loss   | -91.4      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 11471      |
# |    reward          | -13.666498 |
# -----------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 5165854.85
# total_reward: 4165854.85
# total_cost: 35343.05
# total_trades: 58204
# Sharpe: 0.808
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 22       |
# |    time_elapsed    | 1017     |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 286      |
# |    critic_loss     | 35.2     |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | -123     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23043    |
# |    reward          | 2.155056 |
# ---------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 12          |
# |    fps             | 22          |
# |    time_elapsed    | 1530        |
# |    total_timesteps | 34716       |
# | train/             |             |
# |    actor_loss      | 138         |
# |    critic_loss     | 19.3        |
# |    ent_coef        | 0.0144      |
# |    ent_coef_loss   | -120        |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 34615       |
# |    reward          | -0.37755346 |
# ------------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 22         |
# |    time_elapsed    | 2044       |
# |    total_timesteps | 46288      |
# | train/             |            |
# |    actor_loss      | 72.2       |
# |    critic_loss     | 12.6       |
# |    ent_coef        | 0.0048     |
# |    ent_coef_loss   | -80.5      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 46187      |
# |    reward          | -0.5829966 |
# -----------------------------------
# day: 2892, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 5050240.12
# total_reward: 4050240.12
# total_cost: 2685.97
# total_trades: 50204
# Sharpe: 0.789
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 22         |
# |    time_elapsed    | 2558       |
# |    total_timesteps | 57860      |
# | train/             |            |
# |    actor_loss      | 48.7       |
# |    critic_loss     | 8.14       |
# |    ent_coef        | 0.00195    |
# |    ent_coef_loss   | -26.7      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 57759      |
# |    reward          | -1.3687768 |
# -----------------------------------

# %% [markdown]
# Trading phrase

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym)
# Out:
# hit end!

# %% [markdown]
# BackTest Phrase

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# perf_stats_all.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.333286
# Cumulative returns     0.334809
# Annual volatility      0.144248
# Sharpe ratio           2.075084
# Calmar ratio           4.220877
# Stability              0.952955
# Max drawdown          -0.078961
# Omega ratio            1.419244
# Sortino ratio          3.130137
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.086769
# Daily value at risk   -0.016986
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (253, 8)
# Annual return          0.335107
# Cumulative returns     0.336639
# Annual volatility      0.145596
# Sharpe ratio           2.066650
# Calmar ratio           3.752275
# Stability              0.946226
# Max drawdown          -0.089308
# Omega ratio            1.410677
# Sortino ratio          3.094274
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.081322
# Daily value at risk   -0.017149
# dtype: float64

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (253, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-07-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>33.329%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>33.481%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.425%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.08</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>4.22</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.896%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.42</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.13</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.699%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.93</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.9</td>
#       <td>2020-09-02</td>
#       <td>2020-10-28</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.56</td>
#       <td>2021-01-20</td>
#       <td>2021-01-29</td>
#       <td>2021-02-08</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.51</td>
#       <td>2021-05-07</td>
#       <td>2021-06-18</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.17</td>
#       <td>2021-02-24</td>
#       <td>2021-03-04</td>
#       <td>2021-03-08</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.86</td>
#       <td>2020-07-22</td>
#       <td>2020-07-31</td>
#       <td>2020-08-05</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# /home/hcaoaf/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py:5277: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.12%</td>
#       <td>-3.49%</td>
#       <td>3.05%</td>
#     </tr>
#   </tbody>
# </table>
# /home/hcaoaf/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py:5277: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
